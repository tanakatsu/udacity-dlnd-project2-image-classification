# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x_max = np.max(x)
    x_min = np.min(x)
    x -= x_min
    x = x / (x_max - x_min)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    one_hot = np.zeros((len(x), 10))
    for l, v in zip(x, one_hot):
        v[l] = 1
    return one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return  tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]),  name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
    conv_num_inputs = x_tensor.get_shape().as_list()[3]
    weight = tf.Variable(tf.truncated_normal((conv_ksize[0], conv_ksize[1], conv_num_inputs, conv_num_outputs)))   
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_strides = [1, conv_strides[0], conv_strides[1], 1]
    pool_ksize = [1, pool_ksize[0], pool_ksize[1], 1]
    pool_strides = [1, pool_strides[0], pool_strides[1], 1]

    hidden = tf.add(tf.nn.conv2d(x_tensor, weight, strides=conv_strides, padding='SAME'), bias)
    hidden = tf.nn.relu(hidden)
    return tf.nn.max_pool(hidden, ksize=pool_ksize, strides=pool_strides, padding='SAME')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    
    shape = x_tensor.get_shape().as_list()
    image_size = shape[1] * shape[2] * shape[3]
    return tf.reshape(x_tensor, [-1, image_size])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    num_inputs = x_tensor.get_shape().as_list()[1]
    weight = tf.Variable(tf.truncated_normal((num_inputs, num_outputs)))   
    bias = tf.Variable(tf.zeros(num_outputs))
    fc = tf.add(tf.matmul(x_tensor, weight), bias)
    
    return tf.nn.relu(fc)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
     
    num_inputs = x_tensor.get_shape().as_list()[1]
    weight = tf.Variable(tf.truncated_normal((num_inputs, num_outputs)))   
    bias = tf.Variable(tf.zeros(num_outputs))
    
    return tf.add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    hidden = conv2d_maxpool(x,  64, (3, 3), (2, 2),  (2,2), (2,2))
    hidden = conv2d_maxpool(x,  64, (3, 3), (2, 2),  (2,2), (2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    hidden = flatten(hidden)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc = fully_conn(hidden, 512)
        
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    logits = output(fc, 10)
    
    # TODO: return output
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = sess.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})
    valid_acc = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print('loss=', loss, ', validation accuracy=',  valid_acc)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 300
batch_size = 64
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    #sess.run(tf.global_variables_initializer())
    sess.run(tf.initialize_all_variables()) #  tensorflow0.11 or older
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss= 489.19 , validation accuracy= 0.2326
# Epoch  2, CIFAR-10 Batch 1:  loss= 347.754 , validation accuracy= 0.2794
# Epoch  3, CIFAR-10 Batch 1:  loss= 299.105 , validation accuracy= 0.309
# Epoch  4, CIFAR-10 Batch 1:  loss= 220.763 , validation accuracy= 0.333
# Epoch  5, CIFAR-10 Batch 1:  loss= 190.436 , validation accuracy= 0.3448
# Epoch  6, CIFAR-10 Batch 1:  loss= 159.278 , validation accuracy= 0.3728
# Epoch  7, CIFAR-10 Batch 1:  loss= 135.786 , validation accuracy= 0.386
# Epoch  8, CIFAR-10 Batch 1:  loss= 117.049 , validation accuracy= 0.3804
# Epoch  9, CIFAR-10 Batch 1:  loss= 110.334 , validation accuracy= 0.3902
# Epoch 10, CIFAR-10 Batch 1:  loss= 120.176 , validation accuracy= 0.3896
# Epoch 11, CIFAR-10 Batch 1:  loss= 98.1016 , validation accuracy= 0.3994
# Epoch 12, CIFAR-10 Batch 1:  loss= 91.5771 , validation accuracy= 0.4006
# Epoch 13, CIFAR-10 Batch 1:  loss= 69.8386 , validation accuracy= 0.4178
# Epoch 14, CIFAR-10 Batch 1:  loss= 72.8786 , validation accuracy= 0.3986
# Epoch 15, CIFAR-10 Batch 1:  loss= 69.947 , validation accuracy= 0.4146
# Epoch 16, CIFAR-10 Batch 1:  loss= 60.1883 , validation accuracy= 0.431
# Epoch 17, CIFAR-10 Batch 1:  loss= 52.3754 , validation accuracy= 0.4394
# Epoch 18, CIFAR-10 Batch 1:  loss= 47.3639 , validation accuracy= 0.4352
# Epoch 19, CIFAR-10 Batch 1:  loss= 41.8921 , validation accuracy= 0.432
# Epoch 20, CIFAR-10 Batch 1:  loss= 41.0623 , validation accuracy= 0.4408
# Epoch 21, CIFAR-10 Batch 1:  loss= 37.9079 , validation accuracy= 0.4514
# Epoch 22, CIFAR-10 Batch 1:  loss= 34.5328 , validation accuracy= 0.4298
# Epoch 23, CIFAR-10 Batch 1:  loss= 36.3037 , validation accuracy= 0.4442
# Epoch 24, CIFAR-10 Batch 1:  loss= 36.0856 , validation accuracy= 0.4468
# Epoch 25, CIFAR-10 Batch 1:  loss= 35.3371 , validation accuracy= 0.4496
# Epoch 26, CIFAR-10 Batch 1:  loss= 39.7406 , validation accuracy= 0.4412
# Epoch 27, CIFAR-10 Batch 1:  loss= 31.6494 , validation accuracy= 0.4408
# Epoch 28, CIFAR-10 Batch 1:  loss= 22.7224 , validation accuracy= 0.4324
# Epoch 29, CIFAR-10 Batch 1:  loss= 18.9789 , validation accuracy= 0.4364
# Epoch 30, CIFAR-10 Batch 1:  loss= 17.8926 , validation accuracy= 0.4344
# Epoch 31, CIFAR-10 Batch 1:  loss= 12.4927 , validation accuracy= 0.4506
# Epoch 32, CIFAR-10 Batch 1:  loss= 16.268 , validation accuracy= 0.4502
# Epoch 33, CIFAR-10 Batch 1:  loss= 18.7731 , validation accuracy= 0.4546
# Epoch 34, CIFAR-10 Batch 1:  loss= 12.065 , validation accuracy= 0.4692
# Epoch 35, CIFAR-10 Batch 1:  loss= 11.4748 , validation accuracy= 0.4604
# Epoch 36, CIFAR-10 Batch 1:  loss= 11.5278 , validation accuracy= 0.4668
# Epoch 37, CIFAR-10 Batch 1:  loss= 8.2393 , validation accuracy= 0.4748
# Epoch 38, CIFAR-10 Batch 1:  loss= 8.39914 , validation accuracy= 0.4716
# Epoch 39, CIFAR-10 Batch 1:  loss= 6.50023 , validation accuracy= 0.4738
# Epoch 40, CIFAR-10 Batch 1:  loss= 6.03317 , validation accuracy= 0.4722
# Epoch 41, CIFAR-10 Batch 1:  loss= 6.98449 , validation accuracy= 0.4716
# Epoch 42, CIFAR-10 Batch 1:  loss= 6.34359 , validation accuracy= 0.468
# Epoch 43, CIFAR-10 Batch 1:  loss= 3.85627 , validation accuracy= 0.461
# Epoch 44, CIFAR-10 Batch 1:  loss= 5.4142 , validation accuracy= 0.4688
# Epoch 45, CIFAR-10 Batch 1:  loss= 1.7065 , validation accuracy= 0.4594
# Epoch 46, CIFAR-10 Batch 1:  loss= 4.30981 , validation accuracy= 0.463
# Epoch 47, CIFAR-10 Batch 1:  loss= 6.99925 , validation accuracy= 0.4522
# Epoch 48, CIFAR-10 Batch 1:  loss= 5.1638 , validation accuracy= 0.458
# Epoch 49, CIFAR-10 Batch 1:  loss= 0.501833 , validation accuracy= 0.4718
# Epoch 50, CIFAR-10 Batch 1:  loss= 0.0316218 , validation accuracy= 0.4618
# Epoch 51, CIFAR-10 Batch 1:  loss= 3.8363 , validation accuracy= 0.4796
# Epoch 52, CIFAR-10 Batch 1:  loss= 5.25971 , validation accuracy= 0.4766
# Epoch 53, CIFAR-10 Batch 1:  loss= 3.95806 , validation accuracy= 0.4808
# Epoch 54, CIFAR-10 Batch 1:  loss= 2.57702 , validation accuracy= 0.4786
# Epoch 55, CIFAR-10 Batch 1:  loss= 0.687204 , validation accuracy= 0.465
# Epoch 56, CIFAR-10 Batch 1:  loss= 1.06766 , validation accuracy= 0.4644
# Epoch 57, CIFAR-10 Batch 1:  loss= 2.7282 , validation accuracy= 0.4544
# Epoch 58, CIFAR-10 Batch 1:  loss= 1.18908 , validation accuracy= 0.4582
# Epoch 59, CIFAR-10 Batch 1:  loss= 1.25431 , validation accuracy= 0.4544
# Epoch 60, CIFAR-10 Batch 1:  loss= 1.44197 , validation accuracy= 0.4688
# Epoch 61, CIFAR-10 Batch 1:  loss= 6.88424e-07 , validation accuracy= 0.4752
# Epoch 62, CIFAR-10 Batch 1:  loss= 0.145091 , validation accuracy= 0.467
# Epoch 63, CIFAR-10 Batch 1:  loss= 5.06662e-05 , validation accuracy= 0.4794
# Epoch 64, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4856
# Epoch 65, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4792
# Epoch 66, CIFAR-10 Batch 1:  loss= 0.396332 , validation accuracy= 0.4778
# Epoch 67, CIFAR-10 Batch 1:  loss= 0.132738 , validation accuracy= 0.4744
# Epoch 68, CIFAR-10 Batch 1:  loss= 0.0057315 , validation accuracy= 0.4788
# Epoch 69, CIFAR-10 Batch 1:  loss= 1.26756 , validation accuracy= 0.4788
# Epoch 70, CIFAR-10 Batch 1:  loss= 2.65239e-07 , validation accuracy= 0.491
# Epoch 71, CIFAR-10 Batch 1:  loss= 5.77204e-06 , validation accuracy= 0.4858
# Epoch 72, CIFAR-10 Batch 1:  loss= 1.13249e-07 , validation accuracy= 0.4768
# Epoch 73, CIFAR-10 Batch 1:  loss= 1.3113e-07 , validation accuracy= 0.4776
# Epoch 74, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4848
# Epoch 75, CIFAR-10 Batch 1:  loss= 0.312414 , validation accuracy= 0.4776
# Epoch 76, CIFAR-10 Batch 1:  loss= 2.98023e-09 , validation accuracy= 0.4786
# Epoch 77, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.486
# Epoch 78, CIFAR-10 Batch 1:  loss= 0.0635433 , validation accuracy= 0.477
# Epoch 79, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4806
# Epoch 80, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4828
# Epoch 81, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4928
# Epoch 82, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4856
# Epoch 83, CIFAR-10 Batch 1:  loss= 6.85452e-08 , validation accuracy= 0.4808
# Epoch 84, CIFAR-10 Batch 1:  loss= 2.08616e-08 , validation accuracy= 0.4898
# Epoch 85, CIFAR-10 Batch 1:  loss= 0.362696 , validation accuracy= 0.4918
# Epoch 86, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4954
# Epoch 87, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4804
# Epoch 88, CIFAR-10 Batch 1:  loss= 5.96046e-09 , validation accuracy= 0.481
# Epoch 89, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4962
# Epoch 90, CIFAR-10 Batch 1:  loss= 8.9407e-09 , validation accuracy= 0.4874
# Epoch 91, CIFAR-10 Batch 1:  loss= 8.40418e-07 , validation accuracy= 0.4892
# Epoch 92, CIFAR-10 Batch 1:  loss= 3.18883e-07 , validation accuracy= 0.4888
# Epoch 93, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4814
# Epoch 94, CIFAR-10 Batch 1:  loss= 0.000508753 , validation accuracy= 0.4944
# Epoch 95, CIFAR-10 Batch 1:  loss= 2.39972e-05 , validation accuracy= 0.493
# Epoch 96, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4972
# Epoch 97, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4922
# Epoch 98, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.486
# Epoch 99, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.492
# Epoch 100, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4936
# Epoch 101, CIFAR-10 Batch 1:  loss= 0.0777051 , validation accuracy= 0.4924
# Epoch 102, CIFAR-10 Batch 1:  loss= 0.000119519 , validation accuracy= 0.5006
# Epoch 103, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5024
# Epoch 104, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4902
# Epoch 105, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.506
# Epoch 106, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4936
# Epoch 107, CIFAR-10 Batch 1:  loss= 2.98023e-09 , validation accuracy= 0.4932
# Epoch 108, CIFAR-10 Batch 1:  loss= 8.84224e-05 , validation accuracy= 0.5026
# Epoch 109, CIFAR-10 Batch 1:  loss= 0.32554 , validation accuracy= 0.4824
# Epoch 110, CIFAR-10 Batch 1:  loss= 1.73568e-05 , validation accuracy= 0.485
# Epoch 111, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4904
# Epoch 112, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4992
# Epoch 113, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4894
# Epoch 114, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4818
# Epoch 115, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.491
# Epoch 116, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4964
# Epoch 117, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4982
# Epoch 118, CIFAR-10 Batch 1:  loss= 2.98023e-09 , validation accuracy= 0.503
# Epoch 119, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4892
# Epoch 120, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5078
# Epoch 121, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4914
# Epoch 122, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5004
# Epoch 123, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5006
# Epoch 124, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4932
# Epoch 125, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4858
# Epoch 126, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4954
# Epoch 127, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4962
# Epoch 128, CIFAR-10 Batch 1:  loss= 8.04271e-05 , validation accuracy= 0.4888
# Epoch 129, CIFAR-10 Batch 1:  loss= 3.12612e-06 , validation accuracy= 0.5036
# Epoch 130, CIFAR-10 Batch 1:  loss= 0.0809515 , validation accuracy= 0.5108
# Epoch 131, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4974
# Epoch 132, CIFAR-10 Batch 1:  loss= 5.96046e-08 , validation accuracy= 0.501
# Epoch 133, CIFAR-10 Batch 1:  loss= 0.134187 , validation accuracy= 0.5042
# Epoch 134, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5044
# Epoch 135, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.494
# Epoch 136, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5028
# Epoch 137, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5032
# Epoch 138, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4994
# Epoch 139, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5036
# Epoch 140, CIFAR-10 Batch 1:  loss= 2.98023e-09 , validation accuracy= 0.49
# Epoch 141, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5044
# Epoch 142, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5026
# Epoch 143, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5062
# Epoch 144, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5
# Epoch 145, CIFAR-10 Batch 1:  loss= 2.09363e-05 , validation accuracy= 0.5044
# Epoch 146, CIFAR-10 Batch 1:  loss= 7.75336e-06 , validation accuracy= 0.4992
# Epoch 147, CIFAR-10 Batch 1:  loss= 1.87754e-07 , validation accuracy= 0.4992
# Epoch 148, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5048
# Epoch 149, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4958
# Epoch 150, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5008
# Epoch 151, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4982
# Epoch 152, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5002
# Epoch 153, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.505
# Epoch 154, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5038
# Epoch 155, CIFAR-10 Batch 1:  loss= 1.49012e-08 , validation accuracy= 0.5124
# Epoch 156, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.507
# Epoch 157, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.507
# Epoch 158, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5008
# Epoch 159, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5138
# Epoch 160, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5124
# Epoch 161, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5046
# Epoch 162, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.497
# Epoch 163, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5004
# Epoch 164, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5076
# Epoch 165, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5152
# Epoch 166, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5108
# Epoch 167, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5082
# Epoch 168, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5166
# Epoch 169, CIFAR-10 Batch 1:  loss= 1.67781e-06 , validation accuracy= 0.5116
# Epoch 170, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.502
# Epoch 171, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5094
# Epoch 172, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5062
# Epoch 173, CIFAR-10 Batch 1:  loss= 6.5565e-08 , validation accuracy= 0.5098
# Epoch 174, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5114
# Epoch 175, CIFAR-10 Batch 1:  loss= 6.1094e-07 , validation accuracy= 0.5036
# Epoch 176, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5038
# Epoch 177, CIFAR-10 Batch 1:  loss= 0.356203 , validation accuracy= 0.5106
# Epoch 178, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5086
# Epoch 179, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5004
# Epoch 180, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5118
# Epoch 181, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4998
# Epoch 182, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5084
# Epoch 183, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5034
# Epoch 184, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.506
# Epoch 185, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5114
# Epoch 186, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.509
# Epoch 187, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.509
# Epoch 188, CIFAR-10 Batch 1:  loss= 6.85452e-08 , validation accuracy= 0.5088
# Epoch 189, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5058
# Epoch 190, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5018
# Epoch 191, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5094
# Epoch 192, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5086
# Epoch 193, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5174
# Epoch 194, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5122
# Epoch 195, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5108
# Epoch 196, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.512
# Epoch 197, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.518
# Epoch 198, CIFAR-10 Batch 1:  loss= 2.60757e-06 , validation accuracy= 0.505
# Epoch 199, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5088
# Epoch 200, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4986
# Epoch 201, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5114
# Epoch 202, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.504
# Epoch 203, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.4948
# Epoch 204, CIFAR-10 Batch 1:  loss= 1.19209e-08 , validation accuracy= 0.5058
# Epoch 205, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5086
# Epoch 206, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5058
# Epoch 207, CIFAR-10 Batch 1:  loss= 4.17232e-08 , validation accuracy= 0.5146
# Epoch 208, CIFAR-10 Batch 1:  loss= 4.76837e-08 , validation accuracy= 0.5082
# Epoch 209, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.504
# Epoch 210, CIFAR-10 Batch 1:  loss= 4.90796e-06 , validation accuracy= 0.5052
# Epoch 211, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.504
# Epoch 212, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5102
# Epoch 213, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.505
# Epoch 214, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5138
# Epoch 215, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5088
# Epoch 216, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5158
# Epoch 217, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5096
# Epoch 218, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5016
# Epoch 219, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5102
# Epoch 220, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.499
# Epoch 221, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5072
# Epoch 222, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5102
# Epoch 223, CIFAR-10 Batch 1:  loss= 2.98023e-09 , validation accuracy= 0.5072
# Epoch 224, CIFAR-10 Batch 1:  loss= 7.74859e-08 , validation accuracy= 0.5024
# Epoch 225, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5052
# Epoch 226, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5112
# Epoch 227, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5064
# Epoch 228, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5214
# Epoch 229, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.511
# Epoch 230, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5144
# Epoch 231, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5148
# Epoch 232, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5212
# Epoch 233, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5144
# Epoch 234, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5128
# Epoch 235, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5046
# Epoch 236, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.522
# Epoch 237, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5162
# Epoch 238, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5108
# Epoch 239, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5188
# Epoch 240, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5104
# Epoch 241, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.516
# Epoch 242, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5092
# Epoch 243, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5018
# Epoch 244, CIFAR-10 Batch 1:  loss= 5.96046e-08 , validation accuracy= 0.5052
# Epoch 245, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5084
# Epoch 246, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5116
# Epoch 247, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5048
# Epoch 248, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5126
# Epoch 249, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5066
# Epoch 250, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5094
# Epoch 251, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5236
# Epoch 252, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5126
# Epoch 253, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.515
# Epoch 254, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5144
# Epoch 255, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5084
# Epoch 256, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5176
# Epoch 257, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.518
# Epoch 258, CIFAR-10 Batch 1:  loss= 2.04436e-06 , validation accuracy= 0.5124
# Epoch 259, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.518
# Epoch 260, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5152
# Epoch 261, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5142
# Epoch 262, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5064
# Epoch 263, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5232
# Epoch 264, CIFAR-10 Batch 1:  loss= 1.19209e-08 , validation accuracy= 0.5136
# Epoch 265, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5188
# Epoch 266, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5226
# Epoch 267, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5174
# Epoch 268, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.523
# Epoch 269, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5046
# Epoch 270, CIFAR-10 Batch 1:  loss= 0.333372 , validation accuracy= 0.519
# Epoch 271, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5202
# Epoch 272, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5126
# Epoch 273, CIFAR-10 Batch 1:  loss= 4.47034e-08 , validation accuracy= 0.5188
# Epoch 274, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5168
# Epoch 275, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5232
# Epoch 276, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.505
# Epoch 277, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.509
# Epoch 278, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5074
# Epoch 279, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5074
# Epoch 280, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5164
# Epoch 281, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.508
# Epoch 282, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5052
# Epoch 283, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5078
# Epoch 284, CIFAR-10 Batch 1:  loss= 5.96046e-09 , validation accuracy= 0.5064
# Epoch 285, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.516
# Epoch 286, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5148
# Epoch 287, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5194
# Epoch 288, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5154
# Epoch 289, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5024
# Epoch 290, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5138
# Epoch 291, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5146
# Epoch 292, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5124
# Epoch 293, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5116
# Epoch 294, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5168
# Epoch 295, CIFAR-10 Batch 1:  loss= 3.65648e-06 , validation accuracy= 0.5174
# Epoch 296, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5146
# Epoch 297, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5068
# Epoch 298, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5166
# Epoch 299, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5018
# Epoch 300, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.514

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    #sess.run(tf.global_variables_initializer())
    sess.run(tf.initialize_all_variables()) #  tensorflow0.11 or older
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss= 308.991 , validation accuracy= 0.2546
# Epoch  1, CIFAR-10 Batch 2:  loss= 291.248 , validation accuracy= 0.2762
# Epoch  1, CIFAR-10 Batch 3:  loss= 214.699 , validation accuracy= 0.3096
# Epoch  1, CIFAR-10 Batch 4:  loss= 124.54 , validation accuracy= 0.3322
# Epoch  1, CIFAR-10 Batch 5:  loss= 182.487 , validation accuracy= 0.3404
# Epoch  2, CIFAR-10 Batch 1:  loss= 137.237 , validation accuracy= 0.3662
# Epoch  2, CIFAR-10 Batch 2:  loss= 150.236 , validation accuracy= 0.3636
# Epoch  2, CIFAR-10 Batch 3:  loss= 131.837 , validation accuracy= 0.3798
# Epoch  2, CIFAR-10 Batch 4:  loss= 80.6439 , validation accuracy= 0.3834
# Epoch  2, CIFAR-10 Batch 5:  loss= 114.594 , validation accuracy= 0.4038
# Epoch  3, CIFAR-10 Batch 1:  loss= 81.657 , validation accuracy= 0.4202
# Epoch  3, CIFAR-10 Batch 2:  loss= 110.222 , validation accuracy= 0.4092
# Epoch  3, CIFAR-10 Batch 3:  loss= 98.9447 , validation accuracy= 0.4148
# Epoch  3, CIFAR-10 Batch 4:  loss= 64.9851 , validation accuracy= 0.4136
# Epoch  3, CIFAR-10 Batch 5:  loss= 82.5381 , validation accuracy= 0.436
# Epoch  4, CIFAR-10 Batch 1:  loss= 63.8583 , validation accuracy= 0.4418
# Epoch  4, CIFAR-10 Batch 2:  loss= 82.7345 , validation accuracy= 0.4302
# Epoch  4, CIFAR-10 Batch 3:  loss= 84.308 , validation accuracy= 0.4416
# Epoch  4, CIFAR-10 Batch 4:  loss= 56.7653 , validation accuracy= 0.446
# Epoch  4, CIFAR-10 Batch 5:  loss= 62.5102 , validation accuracy= 0.4548
# Epoch  5, CIFAR-10 Batch 1:  loss= 42.1411 , validation accuracy= 0.4474
# Epoch  5, CIFAR-10 Batch 2:  loss= 64.1947 , validation accuracy= 0.4466
# Epoch  5, CIFAR-10 Batch 3:  loss= 60.1924 , validation accuracy= 0.4566
# Epoch  5, CIFAR-10 Batch 4:  loss= 56.6809 , validation accuracy= 0.4506
# Epoch  5, CIFAR-10 Batch 5:  loss= 47.8336 , validation accuracy= 0.4648
# Epoch  6, CIFAR-10 Batch 1:  loss= 33.8069 , validation accuracy= 0.4726
# Epoch  6, CIFAR-10 Batch 2:  loss= 53.9456 , validation accuracy= 0.4646
# Epoch  6, CIFAR-10 Batch 3:  loss= 52.1019 , validation accuracy= 0.4488
# Epoch  6, CIFAR-10 Batch 4:  loss= 43.9589 , validation accuracy= 0.469
# Epoch  6, CIFAR-10 Batch 5:  loss= 44.8884 , validation accuracy= 0.465
# Epoch  7, CIFAR-10 Batch 1:  loss= 34.811 , validation accuracy= 0.4754
# Epoch  7, CIFAR-10 Batch 2:  loss= 44.8547 , validation accuracy= 0.4666
# Epoch  7, CIFAR-10 Batch 3:  loss= 37.7196 , validation accuracy= 0.469
# Epoch  7, CIFAR-10 Batch 4:  loss= 37.4221 , validation accuracy= 0.4756
# Epoch  7, CIFAR-10 Batch 5:  loss= 33.1577 , validation accuracy= 0.4736
# Epoch  8, CIFAR-10 Batch 1:  loss= 33.3677 , validation accuracy= 0.478
# Epoch  8, CIFAR-10 Batch 2:  loss= 25.7182 , validation accuracy= 0.4772
# Epoch  8, CIFAR-10 Batch 3:  loss= 27.3262 , validation accuracy= 0.477
# Epoch  8, CIFAR-10 Batch 4:  loss= 27.5067 , validation accuracy= 0.464
# Epoch  8, CIFAR-10 Batch 5:  loss= 24.2278 , validation accuracy= 0.4874
# Epoch  9, CIFAR-10 Batch 1:  loss= 26.5774 , validation accuracy= 0.4916
# Epoch  9, CIFAR-10 Batch 2:  loss= 19.5347 , validation accuracy= 0.4766
# Epoch  9, CIFAR-10 Batch 3:  loss= 18.2422 , validation accuracy= 0.49
# Epoch  9, CIFAR-10 Batch 4:  loss= 21.9299 , validation accuracy= 0.4624
# Epoch  9, CIFAR-10 Batch 5:  loss= 17.5368 , validation accuracy= 0.4792
# Epoch 10, CIFAR-10 Batch 1:  loss= 21.1944 , validation accuracy= 0.4954
# Epoch 10, CIFAR-10 Batch 2:  loss= 15.1674 , validation accuracy= 0.4726
# Epoch 10, CIFAR-10 Batch 3:  loss= 15.0754 , validation accuracy= 0.4998
# Epoch 10, CIFAR-10 Batch 4:  loss= 17.1296 , validation accuracy= 0.4794
# Epoch 10, CIFAR-10 Batch 5:  loss= 14.0048 , validation accuracy= 0.4866
# Epoch 11, CIFAR-10 Batch 1:  loss= 15.9284 , validation accuracy= 0.4968
# Epoch 11, CIFAR-10 Batch 2:  loss= 10.7756 , validation accuracy= 0.477
# Epoch 11, CIFAR-10 Batch 3:  loss= 10.3904 , validation accuracy= 0.498
# Epoch 11, CIFAR-10 Batch 4:  loss= 13.905 , validation accuracy= 0.4868
# Epoch 11, CIFAR-10 Batch 5:  loss= 11.3487 , validation accuracy= 0.4856
# Epoch 12, CIFAR-10 Batch 1:  loss= 13.4215 , validation accuracy= 0.4964
# Epoch 12, CIFAR-10 Batch 2:  loss= 8.58319 , validation accuracy= 0.4886
# Epoch 12, CIFAR-10 Batch 3:  loss= 8.72076 , validation accuracy= 0.4968
# Epoch 12, CIFAR-10 Batch 4:  loss= 11.1299 , validation accuracy= 0.4934
# Epoch 12, CIFAR-10 Batch 5:  loss= 7.74704 , validation accuracy= 0.491
# Epoch 13, CIFAR-10 Batch 1:  loss= 10.2324 , validation accuracy= 0.5058
# Epoch 13, CIFAR-10 Batch 2:  loss= 7.01354 , validation accuracy= 0.4932
# Epoch 13, CIFAR-10 Batch 3:  loss= 5.60251 , validation accuracy= 0.4988
# Epoch 13, CIFAR-10 Batch 4:  loss= 8.18665 , validation accuracy= 0.502
# Epoch 13, CIFAR-10 Batch 5:  loss= 6.31601 , validation accuracy= 0.4946
# Epoch 14, CIFAR-10 Batch 1:  loss= 8.65272 , validation accuracy= 0.513
# Epoch 14, CIFAR-10 Batch 2:  loss= 5.39123 , validation accuracy= 0.498
# Epoch 14, CIFAR-10 Batch 3:  loss= 4.74222 , validation accuracy= 0.5096
# Epoch 14, CIFAR-10 Batch 4:  loss= 6.76645 , validation accuracy= 0.5062
# Epoch 14, CIFAR-10 Batch 5:  loss= 5.47672 , validation accuracy= 0.4912
# Epoch 15, CIFAR-10 Batch 1:  loss= 8.71769 , validation accuracy= 0.5096
# Epoch 15, CIFAR-10 Batch 2:  loss= 4.27431 , validation accuracy= 0.5004
# Epoch 15, CIFAR-10 Batch 3:  loss= 3.89284 , validation accuracy= 0.5078
# Epoch 15, CIFAR-10 Batch 4:  loss= 5.08114 , validation accuracy= 0.5146
# Epoch 15, CIFAR-10 Batch 5:  loss= 4.87273 , validation accuracy= 0.4958
# Epoch 16, CIFAR-10 Batch 1:  loss= 8.13984 , validation accuracy= 0.5106
# Epoch 16, CIFAR-10 Batch 2:  loss= 4.43697 , validation accuracy= 0.4974
# Epoch 16, CIFAR-10 Batch 3:  loss= 2.61689 , validation accuracy= 0.5146
# Epoch 16, CIFAR-10 Batch 4:  loss= 3.87966 , validation accuracy= 0.5132
# Epoch 16, CIFAR-10 Batch 5:  loss= 3.07504 , validation accuracy= 0.4946
# Epoch 17, CIFAR-10 Batch 1:  loss= 7.62622 , validation accuracy= 0.5206
# Epoch 17, CIFAR-10 Batch 2:  loss= 2.37973 , validation accuracy= 0.51
# Epoch 17, CIFAR-10 Batch 3:  loss= 1.49309 , validation accuracy= 0.5002
# Epoch 17, CIFAR-10 Batch 4:  loss= 2.70294 , validation accuracy= 0.5138
# Epoch 17, CIFAR-10 Batch 5:  loss= 2.05685 , validation accuracy= 0.493
# Epoch 18, CIFAR-10 Batch 1:  loss= 6.61539 , validation accuracy= 0.5202
# Epoch 18, CIFAR-10 Batch 2:  loss= 1.72079 , validation accuracy= 0.5128
# Epoch 18, CIFAR-10 Batch 3:  loss= 1.16937 , validation accuracy= 0.4966
# Epoch 18, CIFAR-10 Batch 4:  loss= 2.58734 , validation accuracy= 0.5106
# Epoch 18, CIFAR-10 Batch 5:  loss= 1.46799 , validation accuracy= 0.4996
# Epoch 19, CIFAR-10 Batch 1:  loss= 3.21095 , validation accuracy= 0.5228
# Epoch 19, CIFAR-10 Batch 2:  loss= 2.01781 , validation accuracy= 0.5086
# Epoch 19, CIFAR-10 Batch 3:  loss= 0.299761 , validation accuracy= 0.5196
# Epoch 19, CIFAR-10 Batch 4:  loss= 1.892 , validation accuracy= 0.509
# Epoch 19, CIFAR-10 Batch 5:  loss= 3.56604 , validation accuracy= 0.5032
# Epoch 20, CIFAR-10 Batch 1:  loss= 3.63237 , validation accuracy= 0.5238
# Epoch 20, CIFAR-10 Batch 2:  loss= 0.817796 , validation accuracy= 0.5088
# Epoch 20, CIFAR-10 Batch 3:  loss= 0.452562 , validation accuracy= 0.5146
# Epoch 20, CIFAR-10 Batch 4:  loss= 2.71929 , validation accuracy= 0.5024
# Epoch 20, CIFAR-10 Batch 5:  loss= 0.948175 , validation accuracy= 0.503
# Epoch 21, CIFAR-10 Batch 1:  loss= 2.37328 , validation accuracy= 0.5242
# Epoch 21, CIFAR-10 Batch 2:  loss= 0.432758 , validation accuracy= 0.5088
# Epoch 21, CIFAR-10 Batch 3:  loss= 0.452021 , validation accuracy= 0.5184
# Epoch 21, CIFAR-10 Batch 4:  loss= 1.73244 , validation accuracy= 0.5124
# Epoch 21, CIFAR-10 Batch 5:  loss= 2.55201 , validation accuracy= 0.5004
# Epoch 22, CIFAR-10 Batch 1:  loss= 2.18205 , validation accuracy= 0.5174
# Epoch 22, CIFAR-10 Batch 2:  loss= 0.553381 , validation accuracy= 0.5118
# Epoch 22, CIFAR-10 Batch 3:  loss= 0.17258 , validation accuracy= 0.525
# Epoch 22, CIFAR-10 Batch 4:  loss= 0.570438 , validation accuracy= 0.519
# Epoch 22, CIFAR-10 Batch 5:  loss= 1.01022 , validation accuracy= 0.5066
# Epoch 23, CIFAR-10 Batch 1:  loss= 1.36959 , validation accuracy= 0.5292
# Epoch 23, CIFAR-10 Batch 2:  loss= 0.400435 , validation accuracy= 0.5182
# Epoch 23, CIFAR-10 Batch 3:  loss= 0.0272889 , validation accuracy= 0.5244
# Epoch 23, CIFAR-10 Batch 4:  loss= 0.182115 , validation accuracy= 0.531
# Epoch 23, CIFAR-10 Batch 5:  loss= 0.487117 , validation accuracy= 0.5018
# Epoch 24, CIFAR-10 Batch 1:  loss= 0.836254 , validation accuracy= 0.5328
# Epoch 24, CIFAR-10 Batch 2:  loss= 0.399144 , validation accuracy= 0.5054
# Epoch 24, CIFAR-10 Batch 3:  loss= 0.028211 , validation accuracy= 0.5194
# Epoch 24, CIFAR-10 Batch 4:  loss= 0.262662 , validation accuracy= 0.5254
# Epoch 24, CIFAR-10 Batch 5:  loss= 0.574233 , validation accuracy= 0.5138
# Epoch 25, CIFAR-10 Batch 1:  loss= 1.0105 , validation accuracy= 0.5258
# Epoch 25, CIFAR-10 Batch 2:  loss= 0.512994 , validation accuracy= 0.506
# Epoch 25, CIFAR-10 Batch 3:  loss= 0.433323 , validation accuracy= 0.5314
# Epoch 25, CIFAR-10 Batch 4:  loss= 0.00659429 , validation accuracy= 0.5346
# Epoch 25, CIFAR-10 Batch 5:  loss= 0.149908 , validation accuracy= 0.5246
# Epoch 26, CIFAR-10 Batch 1:  loss= 0.521996 , validation accuracy= 0.535
# Epoch 26, CIFAR-10 Batch 2:  loss= 0.289058 , validation accuracy= 0.5178
# Epoch 26, CIFAR-10 Batch 3:  loss= 0.00122555 , validation accuracy= 0.529
# Epoch 26, CIFAR-10 Batch 4:  loss= 0.421511 , validation accuracy= 0.5394
# Epoch 26, CIFAR-10 Batch 5:  loss= 0.147205 , validation accuracy= 0.526
# Epoch 27, CIFAR-10 Batch 1:  loss= 0.561874 , validation accuracy= 0.5368
# Epoch 27, CIFAR-10 Batch 2:  loss= 0.0341497 , validation accuracy= 0.5168
# Epoch 27, CIFAR-10 Batch 3:  loss= 0.0355395 , validation accuracy= 0.5326
# Epoch 27, CIFAR-10 Batch 4:  loss= 0.325461 , validation accuracy= 0.5362
# Epoch 27, CIFAR-10 Batch 5:  loss= 0.273418 , validation accuracy= 0.529
# Epoch 28, CIFAR-10 Batch 1:  loss= 0.501834 , validation accuracy= 0.5384
# Epoch 28, CIFAR-10 Batch 2:  loss= 0.255763 , validation accuracy= 0.5274
# Epoch 28, CIFAR-10 Batch 3:  loss= 0.0113777 , validation accuracy= 0.5428
# Epoch 28, CIFAR-10 Batch 4:  loss= 0.0102767 , validation accuracy= 0.5336
# Epoch 28, CIFAR-10 Batch 5:  loss= 0.0900112 , validation accuracy= 0.5376
# Epoch 29, CIFAR-10 Batch 1:  loss= 0.0827419 , validation accuracy= 0.541
# Epoch 29, CIFAR-10 Batch 2:  loss= 0.186418 , validation accuracy= 0.524
# Epoch 29, CIFAR-10 Batch 3:  loss= 0.0205073 , validation accuracy= 0.535
# Epoch 29, CIFAR-10 Batch 4:  loss= 0.142603 , validation accuracy= 0.533
# Epoch 29, CIFAR-10 Batch 5:  loss= 0.121314 , validation accuracy= 0.5348
# Epoch 30, CIFAR-10 Batch 1:  loss= 0.188048 , validation accuracy= 0.5372
# Epoch 30, CIFAR-10 Batch 2:  loss= 0.0137905 , validation accuracy= 0.5302
# Epoch 30, CIFAR-10 Batch 3:  loss= 0.124535 , validation accuracy= 0.529
# Epoch 30, CIFAR-10 Batch 4:  loss= 0.160404 , validation accuracy= 0.528
# Epoch 30, CIFAR-10 Batch 5:  loss= 0.22229 , validation accuracy= 0.5398
# Epoch 31, CIFAR-10 Batch 1:  loss= 0.00356283 , validation accuracy= 0.5404
# Epoch 31, CIFAR-10 Batch 2:  loss= 0.0933968 , validation accuracy= 0.5392
# Epoch 31, CIFAR-10 Batch 3:  loss= 0.010172 , validation accuracy= 0.532
# Epoch 31, CIFAR-10 Batch 4:  loss= 0.030102 , validation accuracy= 0.5388
# Epoch 31, CIFAR-10 Batch 5:  loss= 0.0381277 , validation accuracy= 0.542
# Epoch 32, CIFAR-10 Batch 1:  loss= 0.0569579 , validation accuracy= 0.5342
# Epoch 32, CIFAR-10 Batch 2:  loss= 0.184848 , validation accuracy= 0.5352
# Epoch 32, CIFAR-10 Batch 3:  loss= 0.0514888 , validation accuracy= 0.5312
# Epoch 32, CIFAR-10 Batch 4:  loss= 0.0457612 , validation accuracy= 0.542
# Epoch 32, CIFAR-10 Batch 5:  loss= 0.0309964 , validation accuracy= 0.5348
# Epoch 33, CIFAR-10 Batch 1:  loss= 0.0333998 , validation accuracy= 0.541
# Epoch 33, CIFAR-10 Batch 2:  loss= 0.00369318 , validation accuracy= 0.5378
# Epoch 33, CIFAR-10 Batch 3:  loss= 0.207129 , validation accuracy= 0.5234
# Epoch 33, CIFAR-10 Batch 4:  loss= 0.0141053 , validation accuracy= 0.5332
# Epoch 33, CIFAR-10 Batch 5:  loss= 0.00370476 , validation accuracy= 0.5314
# Epoch 34, CIFAR-10 Batch 1:  loss= 0.240077 , validation accuracy= 0.532
# Epoch 34, CIFAR-10 Batch 2:  loss= 0.00587048 , validation accuracy= 0.533
# Epoch 34, CIFAR-10 Batch 3:  loss= 0.000764847 , validation accuracy= 0.5218
# Epoch 34, CIFAR-10 Batch 4:  loss= 0.00560193 , validation accuracy= 0.54
# Epoch 34, CIFAR-10 Batch 5:  loss= 0.0845538 , validation accuracy= 0.5322
# Epoch 35, CIFAR-10 Batch 1:  loss= 2.69108e-06 , validation accuracy= 0.5414
# Epoch 35, CIFAR-10 Batch 2:  loss= 0.161806 , validation accuracy= 0.5324
# Epoch 35, CIFAR-10 Batch 3:  loss= 0.00195036 , validation accuracy= 0.5298
# Epoch 35, CIFAR-10 Batch 4:  loss= 0.0156647 , validation accuracy= 0.5432
# Epoch 35, CIFAR-10 Batch 5:  loss= 0.00193154 , validation accuracy= 0.5408
# Epoch 36, CIFAR-10 Batch 1:  loss= 0.00308445 , validation accuracy= 0.5394
# Epoch 36, CIFAR-10 Batch 2:  loss= 0.00138637 , validation accuracy= 0.5422
# Epoch 36, CIFAR-10 Batch 3:  loss= 0.102387 , validation accuracy= 0.5458
# Epoch 36, CIFAR-10 Batch 4:  loss= 0.00274182 , validation accuracy= 0.55
# Epoch 36, CIFAR-10 Batch 5:  loss= 0.000506783 , validation accuracy= 0.549
# Epoch 37, CIFAR-10 Batch 1:  loss= 0.00220681 , validation accuracy= 0.5356
# Epoch 37, CIFAR-10 Batch 2:  loss= 0.0375007 , validation accuracy= 0.547
# Epoch 37, CIFAR-10 Batch 3:  loss= 0.000423724 , validation accuracy= 0.5418
# Epoch 37, CIFAR-10 Batch 4:  loss= 0.00734205 , validation accuracy= 0.5438
# Epoch 37, CIFAR-10 Batch 5:  loss= 0.000715149 , validation accuracy= 0.545
# Epoch 38, CIFAR-10 Batch 1:  loss= 0.001676 , validation accuracy= 0.5396
# Epoch 38, CIFAR-10 Batch 2:  loss= 8.65981e-05 , validation accuracy= 0.5436
# Epoch 38, CIFAR-10 Batch 3:  loss= 0.00134028 , validation accuracy= 0.5476
# Epoch 38, CIFAR-10 Batch 4:  loss= 0.00769996 , validation accuracy= 0.549
# Epoch 38, CIFAR-10 Batch 5:  loss= 7.09855e-05 , validation accuracy= 0.5534
# Epoch 39, CIFAR-10 Batch 1:  loss= 0.109575 , validation accuracy= 0.5484
# Epoch 39, CIFAR-10 Batch 2:  loss= 0.0155425 , validation accuracy= 0.543
# Epoch 39, CIFAR-10 Batch 3:  loss= 0.00229014 , validation accuracy= 0.5516
# Epoch 39, CIFAR-10 Batch 4:  loss= 0.00101169 , validation accuracy= 0.55
# Epoch 39, CIFAR-10 Batch 5:  loss= 0.0653474 , validation accuracy= 0.5536
# Epoch 40, CIFAR-10 Batch 1:  loss= 0.00490058 , validation accuracy= 0.5446
# Epoch 40, CIFAR-10 Batch 2:  loss= 4.75308e-06 , validation accuracy= 0.5498
# Epoch 40, CIFAR-10 Batch 3:  loss= 0.000138885 , validation accuracy= 0.5468
# Epoch 40, CIFAR-10 Batch 4:  loss= 0.00603735 , validation accuracy= 0.5364
# Epoch 40, CIFAR-10 Batch 5:  loss= 0.0459023 , validation accuracy= 0.5424
# Epoch 41, CIFAR-10 Batch 1:  loss= 0.0067088 , validation accuracy= 0.5386
# Epoch 41, CIFAR-10 Batch 2:  loss= 0.023106 , validation accuracy= 0.5512
# Epoch 41, CIFAR-10 Batch 3:  loss= 0.0372344 , validation accuracy= 0.5578
# Epoch 41, CIFAR-10 Batch 4:  loss= 0.00109858 , validation accuracy= 0.553
# Epoch 41, CIFAR-10 Batch 5:  loss= 0.272829 , validation accuracy= 0.551
# Epoch 42, CIFAR-10 Batch 1:  loss= 3.67268e-05 , validation accuracy= 0.5578
# Epoch 42, CIFAR-10 Batch 2:  loss= 0.00219078 , validation accuracy= 0.547
# Epoch 42, CIFAR-10 Batch 3:  loss= 0.00114973 , validation accuracy= 0.5516
# Epoch 42, CIFAR-10 Batch 4:  loss= 0.00426876 , validation accuracy= 0.551
# Epoch 42, CIFAR-10 Batch 5:  loss= 0.00100619 , validation accuracy= 0.5604
# Epoch 43, CIFAR-10 Batch 1:  loss= 0.000100894 , validation accuracy= 0.5474
# Epoch 43, CIFAR-10 Batch 2:  loss= 2.38553e-05 , validation accuracy= 0.5384
# Epoch 43, CIFAR-10 Batch 3:  loss= 0.000479409 , validation accuracy= 0.5552
# Epoch 43, CIFAR-10 Batch 4:  loss= 0.00562909 , validation accuracy= 0.565
# Epoch 43, CIFAR-10 Batch 5:  loss= 0.00194977 , validation accuracy= 0.5536
# Epoch 44, CIFAR-10 Batch 1:  loss= 0.000544713 , validation accuracy= 0.5648
# Epoch 44, CIFAR-10 Batch 2:  loss= 0.0318192 , validation accuracy= 0.5422
# Epoch 44, CIFAR-10 Batch 3:  loss= 0.0011758 , validation accuracy= 0.5628
# Epoch 44, CIFAR-10 Batch 4:  loss= 0.000577164 , validation accuracy= 0.5468
# Epoch 44, CIFAR-10 Batch 5:  loss= 3.02488e-06 , validation accuracy= 0.5568
# Epoch 45, CIFAR-10 Batch 1:  loss= 0.118087 , validation accuracy= 0.5592
# Epoch 45, CIFAR-10 Batch 2:  loss= 0.000110507 , validation accuracy= 0.548
# Epoch 45, CIFAR-10 Batch 3:  loss= 0.000371131 , validation accuracy= 0.5554
# Epoch 45, CIFAR-10 Batch 4:  loss= 0.00369982 , validation accuracy= 0.556
# Epoch 45, CIFAR-10 Batch 5:  loss= 0.000569748 , validation accuracy= 0.5484
# Epoch 46, CIFAR-10 Batch 1:  loss= 0.00132049 , validation accuracy= 0.559
# Epoch 46, CIFAR-10 Batch 2:  loss= 0.00134884 , validation accuracy= 0.5474
# Epoch 46, CIFAR-10 Batch 3:  loss= 0.00289332 , validation accuracy= 0.5608
# Epoch 46, CIFAR-10 Batch 4:  loss= 0.00410812 , validation accuracy= 0.5576
# Epoch 46, CIFAR-10 Batch 5:  loss= 0.0283159 , validation accuracy= 0.5494
# Epoch 47, CIFAR-10 Batch 1:  loss= 0.000398478 , validation accuracy= 0.5612
# Epoch 47, CIFAR-10 Batch 2:  loss= 0.00636064 , validation accuracy= 0.5444
# Epoch 47, CIFAR-10 Batch 3:  loss= 0.00244062 , validation accuracy= 0.5622
# Epoch 47, CIFAR-10 Batch 4:  loss= 0.0128297 , validation accuracy= 0.5634
# Epoch 47, CIFAR-10 Batch 5:  loss= 0.242208 , validation accuracy= 0.5524
# Epoch 48, CIFAR-10 Batch 1:  loss= 0.00100072 , validation accuracy= 0.5602
# Epoch 48, CIFAR-10 Batch 2:  loss= 0.000107022 , validation accuracy= 0.5398
# Epoch 48, CIFAR-10 Batch 3:  loss= 0.00264091 , validation accuracy= 0.5542
# Epoch 48, CIFAR-10 Batch 4:  loss= 0.174951 , validation accuracy= 0.5516
# Epoch 48, CIFAR-10 Batch 5:  loss= 0.00834376 , validation accuracy= 0.549
# Epoch 49, CIFAR-10 Batch 1:  loss= 0.00109313 , validation accuracy= 0.562
# Epoch 49, CIFAR-10 Batch 2:  loss= 0.000677359 , validation accuracy= 0.5484
# Epoch 49, CIFAR-10 Batch 3:  loss= 2.20268e-05 , validation accuracy= 0.5616
# Epoch 49, CIFAR-10 Batch 4:  loss= 0.000225401 , validation accuracy= 0.559
# Epoch 49, CIFAR-10 Batch 5:  loss= 0.00214092 , validation accuracy= 0.565
# Epoch 50, CIFAR-10 Batch 1:  loss= 0.000218626 , validation accuracy= 0.5668
# Epoch 50, CIFAR-10 Batch 2:  loss= 3.18544e-05 , validation accuracy= 0.5454
# Epoch 50, CIFAR-10 Batch 3:  loss= 5.45379e-07 , validation accuracy= 0.5534
# Epoch 50, CIFAR-10 Batch 4:  loss= 0.00104287 , validation accuracy= 0.556
# Epoch 50, CIFAR-10 Batch 5:  loss= 5.93043e-06 , validation accuracy= 0.556
# Epoch 51, CIFAR-10 Batch 1:  loss= 0.00233371 , validation accuracy= 0.563
# Epoch 51, CIFAR-10 Batch 2:  loss= 2.84895e-06 , validation accuracy= 0.545
# Epoch 51, CIFAR-10 Batch 3:  loss= 0.0023167 , validation accuracy= 0.5494
# Epoch 51, CIFAR-10 Batch 4:  loss= 0.0035085 , validation accuracy= 0.549
# Epoch 51, CIFAR-10 Batch 5:  loss= 8.57216e-05 , validation accuracy= 0.562
# Epoch 52, CIFAR-10 Batch 1:  loss= 0.000193013 , validation accuracy= 0.5642
# Epoch 52, CIFAR-10 Batch 2:  loss= 0.000357551 , validation accuracy= 0.5586
# Epoch 52, CIFAR-10 Batch 3:  loss= 0.00204698 , validation accuracy= 0.5578
# Epoch 52, CIFAR-10 Batch 4:  loss= 0.00307041 , validation accuracy= 0.5568
# Epoch 52, CIFAR-10 Batch 5:  loss= 0.000199308 , validation accuracy= 0.563
# Epoch 53, CIFAR-10 Batch 1:  loss= 1.67635e-05 , validation accuracy= 0.5628
# Epoch 53, CIFAR-10 Batch 2:  loss= 0.000168002 , validation accuracy= 0.5506
# Epoch 53, CIFAR-10 Batch 3:  loss= 0.000598358 , validation accuracy= 0.5612
# Epoch 53, CIFAR-10 Batch 4:  loss= 4.90357e-05 , validation accuracy= 0.551
# Epoch 53, CIFAR-10 Batch 5:  loss= 0.00164304 , validation accuracy= 0.5556
# Epoch 54, CIFAR-10 Batch 1:  loss= 0.224656 , validation accuracy= 0.5598
# Epoch 54, CIFAR-10 Batch 2:  loss= 0.00910781 , validation accuracy= 0.5604
# Epoch 54, CIFAR-10 Batch 3:  loss= 0.0035066 , validation accuracy= 0.569
# Epoch 54, CIFAR-10 Batch 4:  loss= 0.0019948 , validation accuracy= 0.5434
# Epoch 54, CIFAR-10 Batch 5:  loss= 0.00095036 , validation accuracy= 0.554
# Epoch 55, CIFAR-10 Batch 1:  loss= 0.00106506 , validation accuracy= 0.5738
# Epoch 55, CIFAR-10 Batch 2:  loss= 3.00079e-05 , validation accuracy= 0.559
# Epoch 55, CIFAR-10 Batch 3:  loss= 0.00279246 , validation accuracy= 0.5634
# Epoch 55, CIFAR-10 Batch 4:  loss= 0.0294585 , validation accuracy= 0.559
# Epoch 55, CIFAR-10 Batch 5:  loss= 0.00398413 , validation accuracy= 0.5528
# Epoch 56, CIFAR-10 Batch 1:  loss= 0.00100261 , validation accuracy= 0.5628
# Epoch 56, CIFAR-10 Batch 2:  loss= 1.7494e-05 , validation accuracy= 0.5594
# Epoch 56, CIFAR-10 Batch 3:  loss= 2.05635e-07 , validation accuracy= 0.5596
# Epoch 56, CIFAR-10 Batch 4:  loss= 0.000530578 , validation accuracy= 0.57
# Epoch 56, CIFAR-10 Batch 5:  loss= 0.0033163 , validation accuracy= 0.5604
# Epoch 57, CIFAR-10 Batch 1:  loss= 0.00045604 , validation accuracy= 0.561
# Epoch 57, CIFAR-10 Batch 2:  loss= 0.12288 , validation accuracy= 0.5572
# Epoch 57, CIFAR-10 Batch 3:  loss= 9.87065e-05 , validation accuracy= 0.5698
# Epoch 57, CIFAR-10 Batch 4:  loss= 5.1595e-05 , validation accuracy= 0.5528
# Epoch 57, CIFAR-10 Batch 5:  loss= 2.26881e-05 , validation accuracy= 0.5684
# Epoch 58, CIFAR-10 Batch 1:  loss= 0.165499 , validation accuracy= 0.5666
# Epoch 58, CIFAR-10 Batch 2:  loss= 1.75478e-05 , validation accuracy= 0.5594
# Epoch 58, CIFAR-10 Batch 3:  loss= 0.000920096 , validation accuracy= 0.5712
# Epoch 58, CIFAR-10 Batch 4:  loss= 0.000244323 , validation accuracy= 0.5576
# Epoch 58, CIFAR-10 Batch 5:  loss= 0.00692686 , validation accuracy= 0.5602
# Epoch 59, CIFAR-10 Batch 1:  loss= 0.00416239 , validation accuracy= 0.564
# Epoch 59, CIFAR-10 Batch 2:  loss= 0.000254849 , validation accuracy= 0.5548
# Epoch 59, CIFAR-10 Batch 3:  loss= 0.0149463 , validation accuracy= 0.57
# Epoch 59, CIFAR-10 Batch 4:  loss= 0.00318324 , validation accuracy= 0.561
# Epoch 59, CIFAR-10 Batch 5:  loss= 0.000152585 , validation accuracy= 0.5676
# Epoch 60, CIFAR-10 Batch 1:  loss= 0.000460252 , validation accuracy= 0.562
# Epoch 60, CIFAR-10 Batch 2:  loss= 4.63505e-05 , validation accuracy= 0.561
# Epoch 60, CIFAR-10 Batch 3:  loss= 0.00118108 , validation accuracy= 0.5642
# Epoch 60, CIFAR-10 Batch 4:  loss= 0.149817 , validation accuracy= 0.5618
# Epoch 60, CIFAR-10 Batch 5:  loss= 0.16205 , validation accuracy= 0.5556
# Epoch 61, CIFAR-10 Batch 1:  loss= 0.00016264 , validation accuracy= 0.562
# Epoch 61, CIFAR-10 Batch 2:  loss= 0.00341749 , validation accuracy= 0.5624
# Epoch 61, CIFAR-10 Batch 3:  loss= 9.73993e-05 , validation accuracy= 0.5614
# Epoch 61, CIFAR-10 Batch 4:  loss= 0.000460909 , validation accuracy= 0.5606
# Epoch 61, CIFAR-10 Batch 5:  loss= 9.2761e-06 , validation accuracy= 0.569
# Epoch 62, CIFAR-10 Batch 1:  loss= 0.000383965 , validation accuracy= 0.5648
# Epoch 62, CIFAR-10 Batch 2:  loss= 0.000283271 , validation accuracy= 0.566
# Epoch 62, CIFAR-10 Batch 3:  loss= 5.58764e-06 , validation accuracy= 0.5686
# Epoch 62, CIFAR-10 Batch 4:  loss= 8.07657e-05 , validation accuracy= 0.5642
# Epoch 62, CIFAR-10 Batch 5:  loss= 6.0914e-05 , validation accuracy= 0.565
# Epoch 63, CIFAR-10 Batch 1:  loss= 8.46164e-05 , validation accuracy= 0.5624
# Epoch 63, CIFAR-10 Batch 2:  loss= 0.00111006 , validation accuracy= 0.5648
# Epoch 63, CIFAR-10 Batch 3:  loss= 0.000332349 , validation accuracy= 0.5616
# Epoch 63, CIFAR-10 Batch 4:  loss= 0.160422 , validation accuracy= 0.555
# Epoch 63, CIFAR-10 Batch 5:  loss= 0.000264259 , validation accuracy= 0.5566
# Epoch 64, CIFAR-10 Batch 1:  loss= 0.000251204 , validation accuracy= 0.5696
# Epoch 64, CIFAR-10 Batch 2:  loss= 0.000703664 , validation accuracy= 0.5538
# Epoch 64, CIFAR-10 Batch 3:  loss= 4.54162e-06 , validation accuracy= 0.5694
# Epoch 64, CIFAR-10 Batch 4:  loss= 0.0554838 , validation accuracy= 0.5604
# Epoch 64, CIFAR-10 Batch 5:  loss= 1.52287e-06 , validation accuracy= 0.5578
# Epoch 65, CIFAR-10 Batch 1:  loss= 0.0022647 , validation accuracy= 0.5666
# Epoch 65, CIFAR-10 Batch 2:  loss= 0.000892175 , validation accuracy= 0.5622
# Epoch 65, CIFAR-10 Batch 3:  loss= 6.89455e-05 , validation accuracy= 0.5702
# Epoch 65, CIFAR-10 Batch 4:  loss= 1.78813e-07 , validation accuracy= 0.5654
# Epoch 65, CIFAR-10 Batch 5:  loss= 0.0013531 , validation accuracy= 0.572
# Epoch 66, CIFAR-10 Batch 1:  loss= 0.0037273 , validation accuracy= 0.5782
# Epoch 66, CIFAR-10 Batch 2:  loss= 0.000118575 , validation accuracy= 0.573
# Epoch 66, CIFAR-10 Batch 3:  loss= 0.00620155 , validation accuracy= 0.5646
# Epoch 66, CIFAR-10 Batch 4:  loss= 0.004836 , validation accuracy= 0.5706
# Epoch 66, CIFAR-10 Batch 5:  loss= 0.111754 , validation accuracy= 0.5674
# Epoch 67, CIFAR-10 Batch 1:  loss= 7.62818e-05 , validation accuracy= 0.5674
# Epoch 67, CIFAR-10 Batch 2:  loss= 4.4458e-05 , validation accuracy= 0.5598
# Epoch 67, CIFAR-10 Batch 3:  loss= 0.000169465 , validation accuracy= 0.566
# Epoch 67, CIFAR-10 Batch 4:  loss= 2.72008e-05 , validation accuracy= 0.5762
# Epoch 67, CIFAR-10 Batch 5:  loss= 0.0013734 , validation accuracy= 0.5722
# Epoch 68, CIFAR-10 Batch 1:  loss= 4.64339e-05 , validation accuracy= 0.5682
# Epoch 68, CIFAR-10 Batch 2:  loss= 1.24275e-06 , validation accuracy= 0.5532
# Epoch 68, CIFAR-10 Batch 3:  loss= 3.9456e-06 , validation accuracy= 0.5598
# Epoch 68, CIFAR-10 Batch 4:  loss= 0.000426239 , validation accuracy= 0.5652
# Epoch 68, CIFAR-10 Batch 5:  loss= 1.0229e-05 , validation accuracy= 0.5806
# Epoch 69, CIFAR-10 Batch 1:  loss= 1.72853e-07 , validation accuracy= 0.5706
# Epoch 69, CIFAR-10 Batch 2:  loss= 0.000152555 , validation accuracy= 0.5532
# Epoch 69, CIFAR-10 Batch 3:  loss= 3.84449e-07 , validation accuracy= 0.5716
# Epoch 69, CIFAR-10 Batch 4:  loss= 0.000131736 , validation accuracy= 0.562
# Epoch 69, CIFAR-10 Batch 5:  loss= 7.00844e-05 , validation accuracy= 0.5718
# Epoch 70, CIFAR-10 Batch 1:  loss= 0.100878 , validation accuracy= 0.566
# Epoch 70, CIFAR-10 Batch 2:  loss= 0.000248571 , validation accuracy= 0.563
# Epoch 70, CIFAR-10 Batch 3:  loss= 3.17375e-06 , validation accuracy= 0.571
# Epoch 70, CIFAR-10 Batch 4:  loss= 2.56893e-05 , validation accuracy= 0.5674
# Epoch 70, CIFAR-10 Batch 5:  loss= 6.44941e-05 , validation accuracy= 0.5762
# Epoch 71, CIFAR-10 Batch 1:  loss= 0.00304808 , validation accuracy= 0.5582
# Epoch 71, CIFAR-10 Batch 2:  loss= 8.07638e-07 , validation accuracy= 0.568
# Epoch 71, CIFAR-10 Batch 3:  loss= 0.0584171 , validation accuracy= 0.568
# Epoch 71, CIFAR-10 Batch 4:  loss= 0.0626423 , validation accuracy= 0.5726
# Epoch 71, CIFAR-10 Batch 5:  loss= 0.000683048 , validation accuracy= 0.565
# Epoch 72, CIFAR-10 Batch 1:  loss= 0.0014643 , validation accuracy= 0.5646
# Epoch 72, CIFAR-10 Batch 2:  loss= 0.000157097 , validation accuracy= 0.5606
# Epoch 72, CIFAR-10 Batch 3:  loss= 2.67066e-05 , validation accuracy= 0.5692
# Epoch 72, CIFAR-10 Batch 4:  loss= 0.000575464 , validation accuracy= 0.5568
# Epoch 72, CIFAR-10 Batch 5:  loss= 0.000758168 , validation accuracy= 0.5672
# Epoch 73, CIFAR-10 Batch 1:  loss= 0.00127947 , validation accuracy= 0.5646
# Epoch 73, CIFAR-10 Batch 2:  loss= 0.000661047 , validation accuracy= 0.5566
# Epoch 73, CIFAR-10 Batch 3:  loss= 0.000102382 , validation accuracy= 0.5612
# Epoch 73, CIFAR-10 Batch 4:  loss= 0.00154284 , validation accuracy= 0.5634
# Epoch 73, CIFAR-10 Batch 5:  loss= 0.00141321 , validation accuracy= 0.5654
# Epoch 74, CIFAR-10 Batch 1:  loss= 7.31315e-05 , validation accuracy= 0.5728
# Epoch 74, CIFAR-10 Batch 2:  loss= 0.00456976 , validation accuracy= 0.5582
# Epoch 74, CIFAR-10 Batch 3:  loss= 4.61919e-06 , validation accuracy= 0.5576
# Epoch 74, CIFAR-10 Batch 4:  loss= 9.17831e-06 , validation accuracy= 0.5498
# Epoch 74, CIFAR-10 Batch 5:  loss= 6.32669e-05 , validation accuracy= 0.5732
# Epoch 75, CIFAR-10 Batch 1:  loss= 0.00414525 , validation accuracy= 0.563
# Epoch 75, CIFAR-10 Batch 2:  loss= 0.00058725 , validation accuracy= 0.5496
# Epoch 75, CIFAR-10 Batch 3:  loss= 0.000413887 , validation accuracy= 0.5644
# Epoch 75, CIFAR-10 Batch 4:  loss= 0.00695824 , validation accuracy= 0.5622
# Epoch 75, CIFAR-10 Batch 5:  loss= 0.00545748 , validation accuracy= 0.5718
# Epoch 76, CIFAR-10 Batch 1:  loss= 0.00113269 , validation accuracy= 0.5742
# Epoch 76, CIFAR-10 Batch 2:  loss= 3.12017e-06 , validation accuracy= 0.557
# Epoch 76, CIFAR-10 Batch 3:  loss= 0.00137356 , validation accuracy= 0.5724
# Epoch 76, CIFAR-10 Batch 4:  loss= 0.000969601 , validation accuracy= 0.5684
# Epoch 76, CIFAR-10 Batch 5:  loss= 0.000114081 , validation accuracy= 0.5772
# Epoch 77, CIFAR-10 Batch 1:  loss= 1.20399e-06 , validation accuracy= 0.5684
# Epoch 77, CIFAR-10 Batch 2:  loss= 0.0008012 , validation accuracy= 0.5678
# Epoch 77, CIFAR-10 Batch 3:  loss= 4.69139e-05 , validation accuracy= 0.5646
# Epoch 77, CIFAR-10 Batch 4:  loss= 5.44131e-06 , validation accuracy= 0.554
# Epoch 77, CIFAR-10 Batch 5:  loss= 3.53772e-05 , validation accuracy= 0.563
# Epoch 78, CIFAR-10 Batch 1:  loss= 0.00157413 , validation accuracy= 0.5656
# Epoch 78, CIFAR-10 Batch 2:  loss= 0.0161754 , validation accuracy= 0.5686
# Epoch 78, CIFAR-10 Batch 3:  loss= 2.30659e-06 , validation accuracy= 0.5684
# Epoch 78, CIFAR-10 Batch 4:  loss= 0.000771952 , validation accuracy= 0.5686
# Epoch 78, CIFAR-10 Batch 5:  loss= 0.000602966 , validation accuracy= 0.568
# Epoch 79, CIFAR-10 Batch 1:  loss= 0.00010297 , validation accuracy= 0.5652
# Epoch 79, CIFAR-10 Batch 2:  loss= 7.4326e-05 , validation accuracy= 0.5684
# Epoch 79, CIFAR-10 Batch 3:  loss= 8.87917e-05 , validation accuracy= 0.5692
# Epoch 79, CIFAR-10 Batch 4:  loss= 1.90132e-06 , validation accuracy= 0.5666
# Epoch 79, CIFAR-10 Batch 5:  loss= 0.000266259 , validation accuracy= 0.5698
# Epoch 80, CIFAR-10 Batch 1:  loss= 0.0923273 , validation accuracy= 0.571
# Epoch 80, CIFAR-10 Batch 2:  loss= 1.63894e-05 , validation accuracy= 0.5702
# Epoch 80, CIFAR-10 Batch 3:  loss= 0.00209234 , validation accuracy= 0.5712
# Epoch 80, CIFAR-10 Batch 4:  loss= 2.55698e-05 , validation accuracy= 0.5718
# Epoch 80, CIFAR-10 Batch 5:  loss= 4.54074e-05 , validation accuracy= 0.5692
# Epoch 81, CIFAR-10 Batch 1:  loss= 1.54669e-06 , validation accuracy= 0.5712
# Epoch 81, CIFAR-10 Batch 2:  loss= 0.000679319 , validation accuracy= 0.576
# Epoch 81, CIFAR-10 Batch 3:  loss= 0.00105799 , validation accuracy= 0.566
# Epoch 81, CIFAR-10 Batch 4:  loss= 0.00158539 , validation accuracy= 0.5686
# Epoch 81, CIFAR-10 Batch 5:  loss= 0.000823974 , validation accuracy= 0.5652
# Epoch 82, CIFAR-10 Batch 1:  loss= 0.000274358 , validation accuracy= 0.5638
# Epoch 82, CIFAR-10 Batch 2:  loss= 5.48299e-05 , validation accuracy= 0.5656
# Epoch 82, CIFAR-10 Batch 3:  loss= 0.000191728 , validation accuracy= 0.5656
# Epoch 82, CIFAR-10 Batch 4:  loss= 1.06094e-06 , validation accuracy= 0.5622
# Epoch 82, CIFAR-10 Batch 5:  loss= 0.00265913 , validation accuracy= 0.572
# Epoch 83, CIFAR-10 Batch 1:  loss= 3.54645e-07 , validation accuracy= 0.5666
# Epoch 83, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5668
# Epoch 83, CIFAR-10 Batch 3:  loss= 5.87101e-07 , validation accuracy= 0.5706
# Epoch 83, CIFAR-10 Batch 4:  loss= 9.53674e-08 , validation accuracy= 0.5634
# Epoch 83, CIFAR-10 Batch 5:  loss= 0.000183293 , validation accuracy= 0.5698
# Epoch 84, CIFAR-10 Batch 1:  loss= 8.55314e-07 , validation accuracy= 0.5618
# Epoch 84, CIFAR-10 Batch 2:  loss= 4.31622e-05 , validation accuracy= 0.5728
# Epoch 84, CIFAR-10 Batch 3:  loss= 0.000152044 , validation accuracy= 0.5608
# Epoch 84, CIFAR-10 Batch 4:  loss= 1.81464e-05 , validation accuracy= 0.5784
# Epoch 84, CIFAR-10 Batch 5:  loss= 0.00427816 , validation accuracy= 0.561
# Epoch 85, CIFAR-10 Batch 1:  loss= 4.36567e-06 , validation accuracy= 0.5716
# Epoch 85, CIFAR-10 Batch 2:  loss= 2.72328e-05 , validation accuracy= 0.5604
# Epoch 85, CIFAR-10 Batch 3:  loss= 2.69749e-05 , validation accuracy= 0.5794
# Epoch 85, CIFAR-10 Batch 4:  loss= 0.00338718 , validation accuracy= 0.5728
# Epoch 85, CIFAR-10 Batch 5:  loss= 0.0926539 , validation accuracy= 0.5698
# Epoch 86, CIFAR-10 Batch 1:  loss= 0.000115141 , validation accuracy= 0.5722
# Epoch 86, CIFAR-10 Batch 2:  loss= 6.5898e-05 , validation accuracy= 0.5678
# Epoch 86, CIFAR-10 Batch 3:  loss= 0.00387092 , validation accuracy= 0.5682
# Epoch 86, CIFAR-10 Batch 4:  loss= 0.00018196 , validation accuracy= 0.5778
# Epoch 86, CIFAR-10 Batch 5:  loss= 0.000288874 , validation accuracy= 0.5742
# Epoch 87, CIFAR-10 Batch 1:  loss= 0.000302918 , validation accuracy= 0.57
# Epoch 87, CIFAR-10 Batch 2:  loss= 0.000140761 , validation accuracy= 0.5706
# Epoch 87, CIFAR-10 Batch 3:  loss= 5.26162e-05 , validation accuracy= 0.5756
# Epoch 87, CIFAR-10 Batch 4:  loss= 0.000232409 , validation accuracy= 0.5732
# Epoch 87, CIFAR-10 Batch 5:  loss= 0.000120109 , validation accuracy= 0.573
# Epoch 88, CIFAR-10 Batch 1:  loss= 0.00098111 , validation accuracy= 0.5784
# Epoch 88, CIFAR-10 Batch 2:  loss= 2.14576e-07 , validation accuracy= 0.5768
# Epoch 88, CIFAR-10 Batch 3:  loss= 0.000117044 , validation accuracy= 0.5726
# Epoch 88, CIFAR-10 Batch 4:  loss= 1.43645e-06 , validation accuracy= 0.5726
# Epoch 88, CIFAR-10 Batch 5:  loss= 0.00457816 , validation accuracy= 0.561
# Epoch 89, CIFAR-10 Batch 1:  loss= 0.001653 , validation accuracy= 0.5686
# Epoch 89, CIFAR-10 Batch 2:  loss= 0.000161557 , validation accuracy= 0.5652
# Epoch 89, CIFAR-10 Batch 3:  loss= 0.00210943 , validation accuracy= 0.5658
# Epoch 89, CIFAR-10 Batch 4:  loss= 1.36195e-06 , validation accuracy= 0.5676
# Epoch 89, CIFAR-10 Batch 5:  loss= 0.00025204 , validation accuracy= 0.5714
# Epoch 90, CIFAR-10 Batch 1:  loss= 0.00706964 , validation accuracy= 0.5676
# Epoch 90, CIFAR-10 Batch 2:  loss= 9.39717e-05 , validation accuracy= 0.5676
# Epoch 90, CIFAR-10 Batch 3:  loss= 0.000131419 , validation accuracy= 0.5714
# Epoch 90, CIFAR-10 Batch 4:  loss= 7.38095e-06 , validation accuracy= 0.5676
# Epoch 90, CIFAR-10 Batch 5:  loss= 0.00480322 , validation accuracy= 0.573
# Epoch 91, CIFAR-10 Batch 1:  loss= 0.000713575 , validation accuracy= 0.5752
# Epoch 91, CIFAR-10 Batch 2:  loss= 0.0001571 , validation accuracy= 0.5712
# Epoch 91, CIFAR-10 Batch 3:  loss= 4.90223e-06 , validation accuracy= 0.569
# Epoch 91, CIFAR-10 Batch 4:  loss= 0.000266713 , validation accuracy= 0.5638
# Epoch 91, CIFAR-10 Batch 5:  loss= 0.00310629 , validation accuracy= 0.5736
# Epoch 92, CIFAR-10 Batch 1:  loss= 7.67126e-05 , validation accuracy= 0.5686
# Epoch 92, CIFAR-10 Batch 2:  loss= 0.0209067 , validation accuracy= 0.57
# Epoch 92, CIFAR-10 Batch 3:  loss= 1.43727e-05 , validation accuracy= 0.5774
# Epoch 92, CIFAR-10 Batch 4:  loss= 9.4638e-05 , validation accuracy= 0.5644
# Epoch 92, CIFAR-10 Batch 5:  loss= 0.00184367 , validation accuracy= 0.5784
# Epoch 93, CIFAR-10 Batch 1:  loss= 0.000246668 , validation accuracy= 0.5726
# Epoch 93, CIFAR-10 Batch 2:  loss= 1.49012e-08 , validation accuracy= 0.5734
# Epoch 93, CIFAR-10 Batch 3:  loss= 0.000804974 , validation accuracy= 0.5762
# Epoch 93, CIFAR-10 Batch 4:  loss= 0.000475205 , validation accuracy= 0.5712
# Epoch 93, CIFAR-10 Batch 5:  loss= 4.84558e-06 , validation accuracy= 0.5804
# Epoch 94, CIFAR-10 Batch 1:  loss= 3.62382e-06 , validation accuracy= 0.5764
# Epoch 94, CIFAR-10 Batch 2:  loss= 4.61081e-05 , validation accuracy= 0.5688
# Epoch 94, CIFAR-10 Batch 3:  loss= 0.00125248 , validation accuracy= 0.5814
# Epoch 94, CIFAR-10 Batch 4:  loss= 9.07646e-05 , validation accuracy= 0.5726
# Epoch 94, CIFAR-10 Batch 5:  loss= 5.78825e-05 , validation accuracy= 0.574
# Epoch 95, CIFAR-10 Batch 1:  loss= 0.000232311 , validation accuracy= 0.5798
# Epoch 95, CIFAR-10 Batch 2:  loss= 3.54645e-07 , validation accuracy= 0.5734
# Epoch 95, CIFAR-10 Batch 3:  loss= 0.000417079 , validation accuracy= 0.5678
# Epoch 95, CIFAR-10 Batch 4:  loss= 8.34452e-07 , validation accuracy= 0.5728
# Epoch 95, CIFAR-10 Batch 5:  loss= 0.000620465 , validation accuracy= 0.5694
# Epoch 96, CIFAR-10 Batch 1:  loss= 0.00108201 , validation accuracy= 0.5774
# Epoch 96, CIFAR-10 Batch 2:  loss= 9.41736e-07 , validation accuracy= 0.5708
# Epoch 96, CIFAR-10 Batch 3:  loss= 1.08478e-06 , validation accuracy= 0.5722
# Epoch 96, CIFAR-10 Batch 4:  loss= 0.000737094 , validation accuracy= 0.5636
# Epoch 96, CIFAR-10 Batch 5:  loss= 7.75476e-05 , validation accuracy= 0.5756
# Epoch 97, CIFAR-10 Batch 1:  loss= 0.000170263 , validation accuracy= 0.5674
# Epoch 97, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5684
# Epoch 97, CIFAR-10 Batch 3:  loss= 1.60932e-07 , validation accuracy= 0.5772
# Epoch 97, CIFAR-10 Batch 4:  loss= 0.000818653 , validation accuracy= 0.5716
# Epoch 97, CIFAR-10 Batch 5:  loss= 0.000769591 , validation accuracy= 0.567
# Epoch 98, CIFAR-10 Batch 1:  loss= 9.35777e-07 , validation accuracy= 0.5712
# Epoch 98, CIFAR-10 Batch 2:  loss= 1.3709e-07 , validation accuracy= 0.5738
# Epoch 98, CIFAR-10 Batch 3:  loss= 2.61417e-05 , validation accuracy= 0.5768
# Epoch 98, CIFAR-10 Batch 4:  loss= 0.00012911 , validation accuracy= 0.5772
# Epoch 98, CIFAR-10 Batch 5:  loss= 0.00465745 , validation accuracy= 0.5638
# Epoch 99, CIFAR-10 Batch 1:  loss= 3.03982e-07 , validation accuracy= 0.5786
# Epoch 99, CIFAR-10 Batch 2:  loss= 7.74859e-08 , validation accuracy= 0.5666
# Epoch 99, CIFAR-10 Batch 3:  loss= 2.98023e-08 , validation accuracy= 0.587
# Epoch 99, CIFAR-10 Batch 4:  loss= 0.000574483 , validation accuracy= 0.5836
# Epoch 99, CIFAR-10 Batch 5:  loss= 3.99747e-05 , validation accuracy= 0.5798
# Epoch 100, CIFAR-10 Batch 1:  loss= 0.00222963 , validation accuracy= 0.575
# Epoch 100, CIFAR-10 Batch 2:  loss= 2.98023e-09 , validation accuracy= 0.5716
# Epoch 100, CIFAR-10 Batch 3:  loss= 8.9407e-09 , validation accuracy= 0.5812
# Epoch 100, CIFAR-10 Batch 4:  loss= 0.00293736 , validation accuracy= 0.5802
# Epoch 100, CIFAR-10 Batch 5:  loss= 0.000754838 , validation accuracy= 0.5704
# Epoch 101, CIFAR-10 Batch 1:  loss= 1.01647e-05 , validation accuracy= 0.5746
# Epoch 101, CIFAR-10 Batch 2:  loss= 9.52157e-05 , validation accuracy= 0.5778
# Epoch 101, CIFAR-10 Batch 3:  loss= 7.89749e-07 , validation accuracy= 0.573
# Epoch 101, CIFAR-10 Batch 4:  loss= 1.12354e-06 , validation accuracy= 0.5808
# Epoch 101, CIFAR-10 Batch 5:  loss= 0.000354021 , validation accuracy= 0.5754
# Epoch 102, CIFAR-10 Batch 1:  loss= 1.16229e-07 , validation accuracy= 0.5784
# Epoch 102, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5726
# Epoch 102, CIFAR-10 Batch 3:  loss= 0.000438238 , validation accuracy= 0.5832
# Epoch 102, CIFAR-10 Batch 4:  loss= 0.0157412 , validation accuracy= 0.5806
# Epoch 102, CIFAR-10 Batch 5:  loss= 1.48815e-05 , validation accuracy= 0.5756
# Epoch 103, CIFAR-10 Batch 1:  loss= 1.03413e-06 , validation accuracy= 0.5816
# Epoch 103, CIFAR-10 Batch 2:  loss= 4.71726e-06 , validation accuracy= 0.577
# Epoch 103, CIFAR-10 Batch 3:  loss= 1.19209e-08 , validation accuracy= 0.5838
# Epoch 103, CIFAR-10 Batch 4:  loss= 0.000377797 , validation accuracy= 0.5812
# Epoch 103, CIFAR-10 Batch 5:  loss= 0.0952356 , validation accuracy= 0.5726
# Epoch 104, CIFAR-10 Batch 1:  loss= 1.21087e-05 , validation accuracy= 0.5732
# Epoch 104, CIFAR-10 Batch 2:  loss= 4.20455e-05 , validation accuracy= 0.581
# Epoch 104, CIFAR-10 Batch 3:  loss= 1.57426e-05 , validation accuracy= 0.5782
# Epoch 104, CIFAR-10 Batch 4:  loss= 0.00077762 , validation accuracy= 0.5706
# Epoch 104, CIFAR-10 Batch 5:  loss= 0.0108942 , validation accuracy= 0.5754
# Epoch 105, CIFAR-10 Batch 1:  loss= 0.00146756 , validation accuracy= 0.5768
# Epoch 105, CIFAR-10 Batch 2:  loss= 1.86553e-05 , validation accuracy= 0.5826
# Epoch 105, CIFAR-10 Batch 3:  loss= 2.08616e-08 , validation accuracy= 0.5836
# Epoch 105, CIFAR-10 Batch 4:  loss= 1.37981e-06 , validation accuracy= 0.5756
# Epoch 105, CIFAR-10 Batch 5:  loss= 2.98023e-09 , validation accuracy= 0.5814
# Epoch 106, CIFAR-10 Batch 1:  loss= 1.80299e-06 , validation accuracy= 0.5792
# Epoch 106, CIFAR-10 Batch 2:  loss= 2.98023e-09 , validation accuracy= 0.5786
# Epoch 106, CIFAR-10 Batch 3:  loss= 1.22189e-07 , validation accuracy= 0.5864
# Epoch 106, CIFAR-10 Batch 4:  loss= 8.24851e-06 , validation accuracy= 0.5772
# Epoch 106, CIFAR-10 Batch 5:  loss= 0.000146866 , validation accuracy= 0.5698
# Epoch 107, CIFAR-10 Batch 1:  loss= 1.2815e-07 , validation accuracy= 0.5828
# Epoch 107, CIFAR-10 Batch 2:  loss= 5.96046e-09 , validation accuracy= 0.567
# Epoch 107, CIFAR-10 Batch 3:  loss= 2.50338e-07 , validation accuracy= 0.5782
# Epoch 107, CIFAR-10 Batch 4:  loss= 1.40067e-06 , validation accuracy= 0.5688
# Epoch 107, CIFAR-10 Batch 5:  loss= 5.38562e-05 , validation accuracy= 0.5728
# Epoch 108, CIFAR-10 Batch 1:  loss= 0.00114182 , validation accuracy= 0.567
# Epoch 108, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5778
# Epoch 108, CIFAR-10 Batch 3:  loss= 2.34524e-05 , validation accuracy= 0.581
# Epoch 108, CIFAR-10 Batch 4:  loss= 6.91409e-07 , validation accuracy= 0.5764
# Epoch 108, CIFAR-10 Batch 5:  loss= 5.63258e-07 , validation accuracy= 0.5802
# Epoch 109, CIFAR-10 Batch 1:  loss= 9.97755e-05 , validation accuracy= 0.5776
# Epoch 109, CIFAR-10 Batch 2:  loss= 1.72853e-07 , validation accuracy= 0.5846
# Epoch 109, CIFAR-10 Batch 3:  loss= 6.64584e-07 , validation accuracy= 0.588
# Epoch 109, CIFAR-10 Batch 4:  loss= 0.0019575 , validation accuracy= 0.5844
# Epoch 109, CIFAR-10 Batch 5:  loss= 7.67364e-05 , validation accuracy= 0.5836
# Epoch 110, CIFAR-10 Batch 1:  loss= 2.56601e-05 , validation accuracy= 0.5724
# Epoch 110, CIFAR-10 Batch 2:  loss= 5.06639e-08 , validation accuracy= 0.575
# Epoch 110, CIFAR-10 Batch 3:  loss= 1.50129e-05 , validation accuracy= 0.5802
# Epoch 110, CIFAR-10 Batch 4:  loss= 0.000201505 , validation accuracy= 0.5704
# Epoch 110, CIFAR-10 Batch 5:  loss= 0.000110075 , validation accuracy= 0.5818
# Epoch 111, CIFAR-10 Batch 1:  loss= 0.000127965 , validation accuracy= 0.5774
# Epoch 111, CIFAR-10 Batch 2:  loss= 1.49653e-05 , validation accuracy= 0.5684
# Epoch 111, CIFAR-10 Batch 3:  loss= 0.00159425 , validation accuracy= 0.5718
# Epoch 111, CIFAR-10 Batch 4:  loss= 2.58671e-06 , validation accuracy= 0.571
# Epoch 111, CIFAR-10 Batch 5:  loss= 0.000103225 , validation accuracy= 0.5754
# Epoch 112, CIFAR-10 Batch 1:  loss= 0.000368719 , validation accuracy= 0.5762
# Epoch 112, CIFAR-10 Batch 2:  loss= 0.000457433 , validation accuracy= 0.574
# Epoch 112, CIFAR-10 Batch 3:  loss= 2.09086e-05 , validation accuracy= 0.5762
# Epoch 112, CIFAR-10 Batch 4:  loss= 0.000308287 , validation accuracy= 0.5796
# Epoch 112, CIFAR-10 Batch 5:  loss= 1.28743e-06 , validation accuracy= 0.5768
# Epoch 113, CIFAR-10 Batch 1:  loss= 0.00109995 , validation accuracy= 0.5818
# Epoch 113, CIFAR-10 Batch 2:  loss= 0.00244009 , validation accuracy= 0.5752
# Epoch 113, CIFAR-10 Batch 3:  loss= 1.56722e-05 , validation accuracy= 0.5814
# Epoch 113, CIFAR-10 Batch 4:  loss= 0.000206721 , validation accuracy= 0.577
# Epoch 113, CIFAR-10 Batch 5:  loss= 0.000152665 , validation accuracy= 0.5846
# Epoch 114, CIFAR-10 Batch 1:  loss= 0.000163139 , validation accuracy= 0.5762
# Epoch 114, CIFAR-10 Batch 2:  loss= 2.53319e-07 , validation accuracy= 0.5796
# Epoch 114, CIFAR-10 Batch 3:  loss= 6.54942e-05 , validation accuracy= 0.5778
# Epoch 114, CIFAR-10 Batch 4:  loss= 0.000338789 , validation accuracy= 0.578
# Epoch 114, CIFAR-10 Batch 5:  loss= 0.000511966 , validation accuracy= 0.5766
# Epoch 115, CIFAR-10 Batch 1:  loss= 0.00160371 , validation accuracy= 0.5762
# Epoch 115, CIFAR-10 Batch 2:  loss= 1.46031e-07 , validation accuracy= 0.5776
# Epoch 115, CIFAR-10 Batch 3:  loss= 2.98023e-09 , validation accuracy= 0.5814
# Epoch 115, CIFAR-10 Batch 4:  loss= 0.000297775 , validation accuracy= 0.583
# Epoch 115, CIFAR-10 Batch 5:  loss= 1.84175e-06 , validation accuracy= 0.5598
# Epoch 116, CIFAR-10 Batch 1:  loss= 8.04348e-05 , validation accuracy= 0.573
# Epoch 116, CIFAR-10 Batch 2:  loss= 2.19796e-05 , validation accuracy= 0.577
# Epoch 116, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5826
# Epoch 116, CIFAR-10 Batch 4:  loss= 0.000212509 , validation accuracy= 0.5694
# Epoch 116, CIFAR-10 Batch 5:  loss= 0.0110881 , validation accuracy= 0.5742
# Epoch 117, CIFAR-10 Batch 1:  loss= 0.00135779 , validation accuracy= 0.585
# Epoch 117, CIFAR-10 Batch 2:  loss= 0.000958357 , validation accuracy= 0.5808
# Epoch 117, CIFAR-10 Batch 3:  loss= 1.13844e-06 , validation accuracy= 0.5846
# Epoch 117, CIFAR-10 Batch 4:  loss= 4.82793e-07 , validation accuracy= 0.5816
# Epoch 117, CIFAR-10 Batch 5:  loss= 1.66295e-06 , validation accuracy= 0.5826
# Epoch 118, CIFAR-10 Batch 1:  loss= 1.78814e-08 , validation accuracy= 0.579
# Epoch 118, CIFAR-10 Batch 2:  loss= 0.000927858 , validation accuracy= 0.5828
# Epoch 118, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5804
# Epoch 118, CIFAR-10 Batch 4:  loss= 1.71235e-05 , validation accuracy= 0.5788
# Epoch 118, CIFAR-10 Batch 5:  loss= 1.25169e-07 , validation accuracy= 0.5822
# Epoch 119, CIFAR-10 Batch 1:  loss= 0.000350138 , validation accuracy= 0.5848
# Epoch 119, CIFAR-10 Batch 2:  loss= 2.26497e-07 , validation accuracy= 0.5742
# Epoch 119, CIFAR-10 Batch 3:  loss= 5.96046e-09 , validation accuracy= 0.5784
# Epoch 119, CIFAR-10 Batch 4:  loss= 1.72256e-06 , validation accuracy= 0.5786
# Epoch 119, CIFAR-10 Batch 5:  loss= 1.87153e-06 , validation accuracy= 0.5766
# Epoch 120, CIFAR-10 Batch 1:  loss= 0.00100769 , validation accuracy= 0.5884
# Epoch 120, CIFAR-10 Batch 2:  loss= 3.03982e-07 , validation accuracy= 0.5764
# Epoch 120, CIFAR-10 Batch 3:  loss= 0.000326606 , validation accuracy= 0.577
# Epoch 120, CIFAR-10 Batch 4:  loss= 0.000610756 , validation accuracy= 0.5732
# Epoch 120, CIFAR-10 Batch 5:  loss= 6.64583e-07 , validation accuracy= 0.5814
# Epoch 121, CIFAR-10 Batch 1:  loss= 0.000768793 , validation accuracy= 0.5748
# Epoch 121, CIFAR-10 Batch 2:  loss= 1.49101e-05 , validation accuracy= 0.5694
# Epoch 121, CIFAR-10 Batch 3:  loss= 9.50676e-07 , validation accuracy= 0.5792
# Epoch 121, CIFAR-10 Batch 4:  loss= 7.03684e-05 , validation accuracy= 0.5756
# Epoch 121, CIFAR-10 Batch 5:  loss= 4.00144e-05 , validation accuracy= 0.5832
# Epoch 122, CIFAR-10 Batch 1:  loss= 0.0236519 , validation accuracy= 0.5774
# Epoch 122, CIFAR-10 Batch 2:  loss= 0.000973026 , validation accuracy= 0.5778
# Epoch 122, CIFAR-10 Batch 3:  loss= 7.7783e-07 , validation accuracy= 0.5872
# Epoch 122, CIFAR-10 Batch 4:  loss= 0.000992429 , validation accuracy= 0.5836
# Epoch 122, CIFAR-10 Batch 5:  loss= 0.000387331 , validation accuracy= 0.583
# Epoch 123, CIFAR-10 Batch 1:  loss= 6.61603e-07 , validation accuracy= 0.584
# Epoch 123, CIFAR-10 Batch 2:  loss= 4.67894e-07 , validation accuracy= 0.5788
# Epoch 123, CIFAR-10 Batch 3:  loss= 2.58792e-05 , validation accuracy= 0.5834
# Epoch 123, CIFAR-10 Batch 4:  loss= 5.48035e-06 , validation accuracy= 0.576
# Epoch 123, CIFAR-10 Batch 5:  loss= 2.86478e-05 , validation accuracy= 0.5758
# Epoch 124, CIFAR-10 Batch 1:  loss= 2.04436e-06 , validation accuracy= 0.581
# Epoch 124, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.578
# Epoch 124, CIFAR-10 Batch 3:  loss= 2.11596e-07 , validation accuracy= 0.5824
# Epoch 124, CIFAR-10 Batch 4:  loss= 5.96046e-09 , validation accuracy= 0.5792
# Epoch 124, CIFAR-10 Batch 5:  loss= 5.78159e-07 , validation accuracy= 0.582
# Epoch 125, CIFAR-10 Batch 1:  loss= 3.14389e-05 , validation accuracy= 0.5788
# Epoch 125, CIFAR-10 Batch 2:  loss= 8.9407e-09 , validation accuracy= 0.5744
# Epoch 125, CIFAR-10 Batch 3:  loss= 3.69239e-06 , validation accuracy= 0.5836
# Epoch 125, CIFAR-10 Batch 4:  loss= 3.66244e-06 , validation accuracy= 0.5762
# Epoch 125, CIFAR-10 Batch 5:  loss= 0.000117368 , validation accuracy= 0.5756
# Epoch 126, CIFAR-10 Batch 1:  loss= 2.98023e-09 , validation accuracy= 0.577
# Epoch 126, CIFAR-10 Batch 2:  loss= 0.000515901 , validation accuracy= 0.5724
# Epoch 126, CIFAR-10 Batch 3:  loss= 3.8743e-08 , validation accuracy= 0.5806
# Epoch 126, CIFAR-10 Batch 4:  loss= 0.000420463 , validation accuracy= 0.5734
# Epoch 126, CIFAR-10 Batch 5:  loss= 0.000133105 , validation accuracy= 0.5744
# Epoch 127, CIFAR-10 Batch 1:  loss= 0.000799744 , validation accuracy= 0.579
# Epoch 127, CIFAR-10 Batch 2:  loss= 8.30751e-06 , validation accuracy= 0.5786
# Epoch 127, CIFAR-10 Batch 3:  loss= 0.000200997 , validation accuracy= 0.5796
# Epoch 127, CIFAR-10 Batch 4:  loss= 0.000884269 , validation accuracy= 0.5726
# ...
# Epoch 258, CIFAR-10 Batch 4:  loss= 0.000798464 , validation accuracy= 0.5844
# Epoch 258, CIFAR-10 Batch 5:  loss= 3.01002e-07 , validation accuracy= 0.5746
# Epoch 259, CIFAR-10 Batch 1:  loss= 5.96046e-09 , validation accuracy= 0.5812
# Epoch 259, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.591
# Epoch 259, CIFAR-10 Batch 3:  loss= 2.14576e-07 , validation accuracy= 0.5918
# Epoch 259, CIFAR-10 Batch 4:  loss= 4.36717e-05 , validation accuracy= 0.5974
# Epoch 259, CIFAR-10 Batch 5:  loss= 6.22791e-06 , validation accuracy= 0.5906
# Epoch 260, CIFAR-10 Batch 1:  loss= 3.37641e-06 , validation accuracy= 0.5904
# Epoch 260, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.59
# Epoch 260, CIFAR-10 Batch 3:  loss= 2.98023e-09 , validation accuracy= 0.592
# Epoch 260, CIFAR-10 Batch 4:  loss= 0.000339617 , validation accuracy= 0.5772
# Epoch 260, CIFAR-10 Batch 5:  loss= 0.000583921 , validation accuracy= 0.582
# Epoch 261, CIFAR-10 Batch 1:  loss= 3.92168e-06 , validation accuracy= 0.59
# Epoch 261, CIFAR-10 Batch 2:  loss= 6.25848e-08 , validation accuracy= 0.5766
# Epoch 261, CIFAR-10 Batch 3:  loss= 2.35437e-07 , validation accuracy= 0.579
# Epoch 261, CIFAR-10 Batch 4:  loss= 0.000687675 , validation accuracy= 0.5722
# Epoch 261, CIFAR-10 Batch 5:  loss= 4.17232e-08 , validation accuracy= 0.5822
# Epoch 262, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.585
# Epoch 262, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5798
# Epoch 262, CIFAR-10 Batch 3:  loss= 1.19209e-08 , validation accuracy= 0.5874
# Epoch 262, CIFAR-10 Batch 4:  loss= 0.00140132 , validation accuracy= 0.5794
# Epoch 262, CIFAR-10 Batch 5:  loss= 1.45979e-05 , validation accuracy= 0.5836
# Epoch 263, CIFAR-10 Batch 1:  loss= 1.71275e-05 , validation accuracy= 0.5864
# Epoch 263, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5954
# Epoch 263, CIFAR-10 Batch 3:  loss= 4.68768e-05 , validation accuracy= 0.587
# Epoch 263, CIFAR-10 Batch 4:  loss= 0.000111866 , validation accuracy= 0.588
# Epoch 263, CIFAR-10 Batch 5:  loss= 1.7851e-06 , validation accuracy= 0.5898
# Epoch 264, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5854
# Epoch 264, CIFAR-10 Batch 2:  loss= 2.08616e-08 , validation accuracy= 0.5856
# Epoch 264, CIFAR-10 Batch 3:  loss= 3.35081e-05 , validation accuracy= 0.5802
# Epoch 264, CIFAR-10 Batch 4:  loss= 0.000827902 , validation accuracy= 0.5816
# Epoch 264, CIFAR-10 Batch 5:  loss= 2.98023e-09 , validation accuracy= 0.5872
# Epoch 265, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5906
# Epoch 265, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5934
# Epoch 265, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5806
# Epoch 265, CIFAR-10 Batch 4:  loss= 1.19209e-08 , validation accuracy= 0.593
# Epoch 265, CIFAR-10 Batch 5:  loss= 4.16587e-05 , validation accuracy= 0.593
# Epoch 266, CIFAR-10 Batch 1:  loss= 1.57948e-06 , validation accuracy= 0.5864
# Epoch 266, CIFAR-10 Batch 2:  loss= 5.96046e-09 , validation accuracy= 0.5872
# Epoch 266, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5828
# Epoch 266, CIFAR-10 Batch 4:  loss= 2.29254e-05 , validation accuracy= 0.5836
# Epoch 266, CIFAR-10 Batch 5:  loss= 2.77444e-06 , validation accuracy= 0.578
# Epoch 267, CIFAR-10 Batch 1:  loss= 1.78814e-08 , validation accuracy= 0.5856
# Epoch 267, CIFAR-10 Batch 2:  loss= 8.9407e-09 , validation accuracy= 0.5864
# Epoch 267, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5958
# Epoch 267, CIFAR-10 Batch 4:  loss= 5.96046e-09 , validation accuracy= 0.5912
# Epoch 267, CIFAR-10 Batch 5:  loss= 3.48685e-07 , validation accuracy= 0.5914
# Epoch 268, CIFAR-10 Batch 1:  loss= 0.00212945 , validation accuracy= 0.5868
# Epoch 268, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5856
# Epoch 268, CIFAR-10 Batch 3:  loss= 0.000175179 , validation accuracy= 0.5876
# Epoch 268, CIFAR-10 Batch 4:  loss= 0.000119676 , validation accuracy= 0.5876
# Epoch 268, CIFAR-10 Batch 5:  loss= 4.23189e-07 , validation accuracy= 0.5888
# Epoch 269, CIFAR-10 Batch 1:  loss= 8.9407e-09 , validation accuracy= 0.5842
# Epoch 269, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5862
# Epoch 269, CIFAR-10 Batch 3:  loss= 2.98023e-09 , validation accuracy= 0.589
# Epoch 269, CIFAR-10 Batch 4:  loss= 0.00115373 , validation accuracy= 0.5798
# Epoch 269, CIFAR-10 Batch 5:  loss= 1.78814e-08 , validation accuracy= 0.5862
# Epoch 270, CIFAR-10 Batch 1:  loss= 1.19209e-08 , validation accuracy= 0.5868
# Epoch 270, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.59
# Epoch 270, CIFAR-10 Batch 3:  loss= 0.000206032 , validation accuracy= 0.5878
# Epoch 270, CIFAR-10 Batch 4:  loss= 1.35299e-06 , validation accuracy= 0.5932
# Epoch 270, CIFAR-10 Batch 5:  loss= 1.27373e-05 , validation accuracy= 0.5874
# Epoch 271, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5888
# Epoch 271, CIFAR-10 Batch 2:  loss= 1.96695e-07 , validation accuracy= 0.5838
# Epoch 271, CIFAR-10 Batch 3:  loss= 3.01002e-07 , validation accuracy= 0.5908
# Epoch 271, CIFAR-10 Batch 4:  loss= 3.06962e-07 , validation accuracy= 0.5958
# Epoch 271, CIFAR-10 Batch 5:  loss= 1.57952e-07 , validation accuracy= 0.5794
# Epoch 272, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5888
# Epoch 272, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.583
# Epoch 272, CIFAR-10 Batch 3:  loss= 2.98023e-09 , validation accuracy= 0.5884
# Epoch 272, CIFAR-10 Batch 4:  loss= 1.3709e-07 , validation accuracy= 0.5844
# Epoch 272, CIFAR-10 Batch 5:  loss= 0.000797247 , validation accuracy= 0.5846
# Epoch 273, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5878
# Epoch 273, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5868
# Epoch 273, CIFAR-10 Batch 3:  loss= 8.07632e-07 , validation accuracy= 0.59
# Epoch 273, CIFAR-10 Batch 4:  loss= 0.0 , validation accuracy= 0.5836
# Epoch 273, CIFAR-10 Batch 5:  loss= 3.20627e-05 , validation accuracy= 0.5738
# Epoch 274, CIFAR-10 Batch 1:  loss= 1.72853e-07 , validation accuracy= 0.5874
# Epoch 274, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5894
# Epoch 274, CIFAR-10 Batch 3:  loss= 3.27825e-08 , validation accuracy= 0.5888
# Epoch 274, CIFAR-10 Batch 4:  loss= 1.1656e-05 , validation accuracy= 0.5764
# Epoch 274, CIFAR-10 Batch 5:  loss= 6.10943e-07 , validation accuracy= 0.5944
# Epoch 275, CIFAR-10 Batch 1:  loss= 0.000191158 , validation accuracy= 0.5906
# Epoch 275, CIFAR-10 Batch 2:  loss= 4.91017e-05 , validation accuracy= 0.595
# Epoch 275, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5902
# Epoch 275, CIFAR-10 Batch 4:  loss= 4.13622e-06 , validation accuracy= 0.5918
# Epoch 275, CIFAR-10 Batch 5:  loss= 6.13922e-07 , validation accuracy= 0.5832
# Epoch 276, CIFAR-10 Batch 1:  loss= 1.25169e-07 , validation accuracy= 0.585
# Epoch 276, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5824
# Epoch 276, CIFAR-10 Batch 3:  loss= 1.27909e-05 , validation accuracy= 0.5918
# Epoch 276, CIFAR-10 Batch 4:  loss= 0.0 , validation accuracy= 0.5922
# Epoch 276, CIFAR-10 Batch 5:  loss= 0.0 , validation accuracy= 0.583
# Epoch 277, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.581
# Epoch 277, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5868
# Epoch 277, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5866
# Epoch 277, CIFAR-10 Batch 4:  loss= 5.06902e-06 , validation accuracy= 0.5898
# Epoch 277, CIFAR-10 Batch 5:  loss= 2.14869e-06 , validation accuracy= 0.5842
# Epoch 278, CIFAR-10 Batch 1:  loss= 2.07714e-06 , validation accuracy= 0.5854
# Epoch 278, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5882
# Epoch 278, CIFAR-10 Batch 3:  loss= 4.17232e-08 , validation accuracy= 0.5906
# Epoch 278, CIFAR-10 Batch 4:  loss= 0.0 , validation accuracy= 0.5918
# Epoch 278, CIFAR-10 Batch 5:  loss= 0.00045396 , validation accuracy= 0.5944
# Epoch 279, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.591
# Epoch 279, CIFAR-10 Batch 2:  loss= 1.63355e-05 , validation accuracy= 0.5852
# Epoch 279, CIFAR-10 Batch 3:  loss= 5.96046e-09 , validation accuracy= 0.5998
# Epoch 279, CIFAR-10 Batch 4:  loss= 2.08616e-08 , validation accuracy= 0.5948
# Epoch 279, CIFAR-10 Batch 5:  loss= 0.0 , validation accuracy= 0.5902
# Epoch 280, CIFAR-10 Batch 1:  loss= 3.6535e-06 , validation accuracy= 0.5812
# Epoch 280, CIFAR-10 Batch 2:  loss= 2.28871e-06 , validation accuracy= 0.593
# Epoch 280, CIFAR-10 Batch 3:  loss= 2.98023e-09 , validation accuracy= 0.5906
# Epoch 280, CIFAR-10 Batch 4:  loss= 6.39178e-06 , validation accuracy= 0.582
# Epoch 280, CIFAR-10 Batch 5:  loss= 0.0 , validation accuracy= 0.5842
# Epoch 281, CIFAR-10 Batch 1:  loss= 6.58623e-07 , validation accuracy= 0.584
# Epoch 281, CIFAR-10 Batch 2:  loss= 2.08616e-08 , validation accuracy= 0.5864
# Epoch 281, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5968
# Epoch 281, CIFAR-10 Batch 4:  loss= 9.83475e-08 , validation accuracy= 0.5904
# Epoch 281, CIFAR-10 Batch 5:  loss= 4.3213e-07 , validation accuracy= 0.5972
# Epoch 282, CIFAR-10 Batch 1:  loss= 2.44378e-07 , validation accuracy= 0.591
# Epoch 282, CIFAR-10 Batch 2:  loss= 1.3113e-07 , validation accuracy= 0.5958
# Epoch 282, CIFAR-10 Batch 3:  loss= 1.87754e-07 , validation accuracy= 0.5908
# Epoch 282, CIFAR-10 Batch 4:  loss= 2.23517e-07 , validation accuracy= 0.5946
# Epoch 282, CIFAR-10 Batch 5:  loss= 1.49012e-08 , validation accuracy= 0.5942
# Epoch 283, CIFAR-10 Batch 1:  loss= 2.08616e-08 , validation accuracy= 0.5862
# Epoch 283, CIFAR-10 Batch 2:  loss= 1.19209e-08 , validation accuracy= 0.5816
# Epoch 283, CIFAR-10 Batch 3:  loss= 2.38418e-07 , validation accuracy= 0.5884
# Epoch 283, CIFAR-10 Batch 4:  loss= 0.0 , validation accuracy= 0.5944
# Epoch 283, CIFAR-10 Batch 5:  loss= 0.0 , validation accuracy= 0.595
# Epoch 284, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5892
# Epoch 284, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5936
# Epoch 284, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5882
# Epoch 284, CIFAR-10 Batch 4:  loss= 0.000194951 , validation accuracy= 0.59
# Epoch 284, CIFAR-10 Batch 5:  loss= 2.98023e-08 , validation accuracy= 0.5848
# Epoch 285, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5892
# Epoch 285, CIFAR-10 Batch 2:  loss= 0.000245781 , validation accuracy= 0.5916
# Epoch 285, CIFAR-10 Batch 3:  loss= 0.000514403 , validation accuracy= 0.5914
# Epoch 285, CIFAR-10 Batch 4:  loss= 4.97694e-07 , validation accuracy= 0.5854
# Epoch 285, CIFAR-10 Batch 5:  loss= 1.36785e-05 , validation accuracy= 0.5806
# Epoch 286, CIFAR-10 Batch 1:  loss= 8.9407e-09 , validation accuracy= 0.583
# Epoch 286, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5902
# Epoch 286, CIFAR-10 Batch 3:  loss= 5.36441e-08 , validation accuracy= 0.595
# Epoch 286, CIFAR-10 Batch 4:  loss= 9.62599e-07 , validation accuracy= 0.5884
# Epoch 286, CIFAR-10 Batch 5:  loss= 3.57628e-08 , validation accuracy= 0.5934
# Epoch 287, CIFAR-10 Batch 1:  loss= 2.98023e-09 , validation accuracy= 0.587
# Epoch 287, CIFAR-10 Batch 2:  loss= 2.53318e-07 , validation accuracy= 0.5836
# Epoch 287, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5986
# Epoch 287, CIFAR-10 Batch 4:  loss= 6.64586e-07 , validation accuracy= 0.5926
# Epoch 287, CIFAR-10 Batch 5:  loss= 2.70193e-05 , validation accuracy= 0.5868
# Epoch 288, CIFAR-10 Batch 1:  loss= 5.21536e-07 , validation accuracy= 0.5828
# Epoch 288, CIFAR-10 Batch 2:  loss= 2.08616e-08 , validation accuracy= 0.5878
# Epoch 288, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5848
# Epoch 288, CIFAR-10 Batch 4:  loss= 0.000754915 , validation accuracy= 0.5888
# Epoch 288, CIFAR-10 Batch 5:  loss= 9.53656e-07 , validation accuracy= 0.5914
# Epoch 289, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.59
# Epoch 289, CIFAR-10 Batch 2:  loss= 2.24817e-05 , validation accuracy= 0.588
# Epoch 289, CIFAR-10 Batch 3:  loss= 4.59308e-05 , validation accuracy= 0.5944
# Epoch 289, CIFAR-10 Batch 4:  loss= 0.0 , validation accuracy= 0.5834
# Epoch 289, CIFAR-10 Batch 5:  loss= 1.46031e-07 , validation accuracy= 0.5822
# Epoch 290, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.5916
# Epoch 290, CIFAR-10 Batch 2:  loss= 4.1964e-05 , validation accuracy= 0.5894
# Epoch 290, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5906
# Epoch 290, CIFAR-10 Batch 4:  loss= 4.30511e-05 , validation accuracy= 0.5838
# Epoch 290, CIFAR-10 Batch 5:  loss= 0.0 , validation accuracy= 0.591
# Epoch 291, CIFAR-10 Batch 1:  loss= 0.0 , validation accuracy= 0.592
# Epoch 291, CIFAR-10 Batch 2:  loss= 2.56299e-07 , validation accuracy= 0.5974
# Epoch 291, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5948
# Epoch 291, CIFAR-10 Batch 4:  loss= 4.17232e-08 , validation accuracy= 0.5862
# Epoch 291, CIFAR-10 Batch 5:  loss= 2.98023e-09 , validation accuracy= 0.5902
# Epoch 292, CIFAR-10 Batch 1:  loss= 3.30804e-07 , validation accuracy= 0.5868
# Epoch 292, CIFAR-10 Batch 2:  loss= 2.69447e-05 , validation accuracy= 0.5964
# Epoch 292, CIFAR-10 Batch 3:  loss= 3.1136e-05 , validation accuracy= 0.5888
# Epoch 292, CIFAR-10 Batch 4:  loss= 3.78487e-07 , validation accuracy= 0.5862
# Epoch 292, CIFAR-10 Batch 5:  loss= 1.66893e-07 , validation accuracy= 0.5854
# Epoch 293, CIFAR-10 Batch 1:  loss= 0.000164723 , validation accuracy= 0.5694
# Epoch 293, CIFAR-10 Batch 2:  loss= 5.28935e-06 , validation accuracy= 0.5898
# Epoch 293, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5938
# Epoch 293, CIFAR-10 Batch 4:  loss= 1.47815e-06 , validation accuracy= 0.5956
# Epoch 293, CIFAR-10 Batch 5:  loss= 0.0 , validation accuracy= 0.5964
# Epoch 294, CIFAR-10 Batch 1:  loss= 6.82464e-07 , validation accuracy= 0.587
# Epoch 294, CIFAR-10 Batch 2:  loss= 1.49012e-08 , validation accuracy= 0.5858
# Epoch 294, CIFAR-10 Batch 3:  loss= 4.70874e-07 , validation accuracy= 0.5864
# Epoch 294, CIFAR-10 Batch 4:  loss= 8.9407e-09 , validation accuracy= 0.5804
# Epoch 294, CIFAR-10 Batch 5:  loss= 0.00234808 , validation accuracy= 0.58
# Epoch 295, CIFAR-10 Batch 1:  loss= 0.000337322 , validation accuracy= 0.5834
# Epoch 295, CIFAR-10 Batch 2:  loss= 2.712e-07 , validation accuracy= 0.588
# Epoch 295, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5986
# Epoch 295, CIFAR-10 Batch 4:  loss= 0.0 , validation accuracy= 0.5842
# Epoch 295, CIFAR-10 Batch 5:  loss= 0.000182832 , validation accuracy= 0.5888
# Epoch 296, CIFAR-10 Batch 1:  loss= 0.000147017 , validation accuracy= 0.596
# Epoch 296, CIFAR-10 Batch 2:  loss= 0.000188707 , validation accuracy= 0.5878
# Epoch 296, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5926
# Epoch 296, CIFAR-10 Batch 4:  loss= 5.96046e-09 , validation accuracy= 0.586
# Epoch 296, CIFAR-10 Batch 5:  loss= 4.17232e-08 , validation accuracy= 0.5842
# Epoch 297, CIFAR-10 Batch 1:  loss= 2.40866e-05 , validation accuracy= 0.5804
# Epoch 297, CIFAR-10 Batch 2:  loss= 9.20952e-05 , validation accuracy= 0.592
# Epoch 297, CIFAR-10 Batch 3:  loss= 3.23334e-06 , validation accuracy= 0.5882
# Epoch 297, CIFAR-10 Batch 4:  loss= 8.9407e-09 , validation accuracy= 0.588
# Epoch 297, CIFAR-10 Batch 5:  loss= 0.0 , validation accuracy= 0.5802
# Epoch 298, CIFAR-10 Batch 1:  loss= 6.29169e-05 , validation accuracy= 0.5874
# Epoch 298, CIFAR-10 Batch 2:  loss= 2.67313e-06 , validation accuracy= 0.5826
# Epoch 298, CIFAR-10 Batch 3:  loss= 0.0 , validation accuracy= 0.5914
# Epoch 298, CIFAR-10 Batch 4:  loss= 9.53672e-08 , validation accuracy= 0.5734
# Epoch 298, CIFAR-10 Batch 5:  loss= 2.17556e-07 , validation accuracy= 0.5862
# Epoch 299, CIFAR-10 Batch 1:  loss= 3.27825e-08 , validation accuracy= 0.581
# Epoch 299, CIFAR-10 Batch 2:  loss= 0.000126787 , validation accuracy= 0.583
# Epoch 299, CIFAR-10 Batch 3:  loss= 2.98023e-09 , validation accuracy= 0.5842
# Epoch 299, CIFAR-10 Batch 4:  loss= 1.90734e-07 , validation accuracy= 0.5834
# Epoch 299, CIFAR-10 Batch 5:  loss= 0.0 , validation accuracy= 0.59
# Epoch 300, CIFAR-10 Batch 1:  loss= 5.96046e-09 , validation accuracy= 0.59
# Epoch 300, CIFAR-10 Batch 2:  loss= 0.0 , validation accuracy= 0.5864
# Epoch 300, CIFAR-10 Batch 3:  loss= 2.98023e-08 , validation accuracy= 0.5858
# Epoch 300, CIFAR-10 Batch 4:  loss= 0.000437685 , validation accuracy= 0.5828
# Epoch 300, CIFAR-10 Batch 5:  loss= 2.76204e-05 , validation accuracy= 0.59

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5900676751592356

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
